# %% [markdown]
# ## import modules
# ## Load the datasets which are scraped
# ## Lemmatizer stopword removal modules
# ## clean skills dataset
# ## filter the data for validation
# ## clean jobs dataset
# ## phrase matcher model to extract skills from job description
# ## create job titles using job progression dictionary and declare set of properly defined titles
# ## clean job titles by fuzzy matching and normalizing against job preogression titles
# ## clean course data
# ## Lemmitization and cleaning columns
# ## merge all description into one
# ## save processed datasets

# %%
import pandas as pd
pd.set_option('display.max_columns', None) 
from os import listdir
import os
import glob
import spacy
from collections import Counter
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import spacy
from spacy.training import Example
from spacy.util import minibatch, compounding
from sklearn.model_selection import train_test_split
from spacy.scorer import Scorer
import re
import nlp
# Out:
# [nltk_data] Downloading package stopwords to /Users/nyzy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## Load the datasets which are scraped

#load data
job_path = "/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/raw/job_data"
courses_path = "/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/raw/courses_data"
skills_path = "/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/skills_dataset/skills_df_updated.csv"

## courses
files_c= [f for f in listdir(courses_path) if f.endswith(".csv")]
df_c = pd.concat([pd.read_csv(os.path.join(courses_path,f)) for f in files_c])

## skills 
#files_s= [f for f in listdir(skills_path) if f.endswith(".csv")]
df_s = pd.read_csv(skills_path)

## jobs
df_j_main_list=[]
job_dir = listdir(job_path)
job_dir.remove('.DS_Store')
for job in job_dir:
    files_j= [f for f in listdir(os.path.join(job_path,job)) if f.endswith(".csv")]
    df_j = pd.concat([pd.read_csv(os.path.join(job_path,job,f)) for f in files_j])
    df_j["searched_title"]=job
    df_j_main_list.append(df_j)
df_j = pd.concat(df_j_main_list)

# %%
df_j
# Out:
#      Unnamed: 0                          company  \
# 0             0               Community Hospital
# 1             1      Mesalands Community College
# 2             2     Cornerstone Healthcare Group
# 3             3  Clinical Management Consultants
# 4             4  Clinical Management Consultants
# ..          ...                              ...
# 100         100                        Bloomberg
# 101         101                        Backblaze
# 102         102        Overhead Door Corporation
# 103         103                        Bloomberg
# 104         104                     Michael Page
#
#                                            viewJobLink  \
# 0    /viewjob?jk=4d8992b619aa6b59&from=vjs&tk=1hf0d...
# 1    /viewjob?jk=808042413e184228&from=vjs&tk=1hf0d...
# 2    /viewjob?jk=662ea1d8fa14338a&from=vjs&tk=1hf0d...
# 3    /viewjob?jk=c4fe7497a96027b4&from=vjs&tk=1hf0d...
# 4    /viewjob?jk=94244e37cfb1aabf&from=vjs&tk=1hf0d...
# ..                                                 ...
# 100  /viewjob?jk=2036d50c7ac01703&from=vjs&tk=1hf0h...
# 101  /viewjob?jk=59b98c76290f5daa&from=vjs&tk=1hf0h...
# 102  /viewjob?jk=e8dfd413b225d5f2&from=vjs&tk=1hf0h...
# 103  /viewjob?jk=0fabc0b0257a039b&from=vjs&tk=1hf0h...
# 104  /viewjob?jk=295a957be37ca331&from=vjs&tk=1hf0h...
#
#                              companyBrandingAttributes  \
# 0    {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
# 1                                                   {}
# 2    {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
# 3    {'logoUrl': 'https://d2q79iu7y748jz.cloudfront...
# 4    {'logoUrl': 'https://d2q79iu7y748jz.cloudfront...
# ..                                                 ...
# 100  {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
# 101  {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
# 102  {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
# 103  {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
# 104  {'headerImageUrl': 'https://d2q79iu7y748jz.clo...
#
#                                    companyOverviewLink  companyRating  \
# 0    https://www.indeed.com/cmp/Community-Hospital-...            3.1
# 1    https://www.indeed.com/cmp/Mesalands-Community...            3.8
# 2    https://www.indeed.com/cmp/Kindred-Hospitals-3...            3.3
# 3    https://www.indeed.com/cmp/Clinical-Management...            4.2
# 4    https://www.indeed.com/cmp/Clinical-Management...            4.2
# ..                                                 ...            ...
# 100  https://www.indeed.com/cmp/Bloomberg?campaigni...            3.9
# 101  https://www.indeed.com/cmp/Backblaze?campaigni...            3.5
# 102  https://www.indeed.com/cmp/Overhead-Door-Corpo...            3.2
# 103  https://www.indeed.com/cmp/Bloomberg?campaigni...            3.9
# 104  https://www.indeed.com/cmp/Michael-Page?campai...            3.7
#
#      companyReviewCount                                       displayTitle  \
# 0                  39.0  System Chief Quality Officer/Regulatory Compli...
# 1                  14.0                            Chief Financial Officer
# 2                5192.0   Chief Operating Officer / Chief Clinical Officer
# 3                  13.0                   Hospital Chief Financial Officer
# 4                  13.0                        Nurse Chief Quality Officer
# ..                  ...                                                ...
# 100               952.0    Product & Organizational Coach - CTO COO Office
# 101                 2.0  Portfolio Manager, PMO (Office of CTO) - Contract
# 102               386.0                           Chief Technology Officer
# 103               952.0            Applied Researcher, Search - CTO Office
# 104               512.0                                         Deputy CTO
#
#      employerAssistEnabled  employerResponsive  expired  \
# 0                    False               False    False
# 1                     True               False    False
# 2                     True               False    False
# 3                    False               False    False
# 4                    False               False    False
# ..                     ...                 ...      ...
# 100                  False               False    False
# 101                  False               False    False
# 102                   True               False    False
# 103                  False               False    False
# 104                  False               False    False
#
#                              featuredCompanyAttributes  featuredEmployer  \
# 0                                                   {}             False
# 1                                                   {}             False
# 2    {'logoUrl': 'https://d2q79iu7y748jz.cloudfront...              True
# 3                                                   {}             False
# 4                                                   {}             False
# ..                                                 ...               ...
# 100                                                 {}             False
# 101                                                 {}             False
# 102                                                 {}             False
# 103                                                 {}             False
# 104                                                 {}             False
#
#      featuredEmployerCandidate  feedId        formattedLocation  \
# 0                        False   50461  Oklahoma City, OK 73159
# 1                        False   50461      Tucumcari, NM 88401
# 2                        False   50461   Indianapolis, IN 46222
# 3                        False   17779                Alamo, TX
# 4                        False   17779                 Mesa, AZ
# ..                         ...     ...                      ...
# 100                      False   11468       New York, NY 10261
# 101                      False   46432                   Remote
# 102                      False  173386     Mount Hope, OH 44660
# 103                      False   11468       New York, NY 10261
# 104                      False  798522              Chicago, IL
#
#     formattedRelativeTime        highVolumeHiringModel  hiringEventJob  \
# 0            30+ days ago  {'highVolumeHiring': False}           False
# 1            30+ days ago  {'highVolumeHiring': False}           False
# 2              5 days ago  {'highVolumeHiring': False}           False
# 3             18 days ago  {'highVolumeHiring': False}           False
# 4               1 day ago  {'highVolumeHiring': False}           False
# ..                    ...                          ...             ...
# 100          30+ days ago  {'highVolumeHiring': False}           False
# 101          30+ days ago  {'highVolumeHiring': False}           False
# 102           11 days ago  {'highVolumeHiring': False}           False
# 103           30 days ago  {'highVolumeHiring': False}           False
# 104            9 days ago  {'highVolumeHiring': False}           False
#
#      indeedApplyEnabled  indeedApplyable  isJobVisited  \
# 0                  True             True         False
# 1                  True             True         False
# 2                  True             True         False
# 3                 False            False         False
# 4                 False            False         False
# ..                  ...              ...           ...
# 100               False            False         False
# 101                True             True         False
# 102                True             True         False
# 103               False            False         False
# 104               False            False         False
#
#      isMobileThirdPartyApplyable  isNoResumeJob  isSubsidiaryJob  \
# 0                          False          False            False
# 1                          False          False            False
# 2                          False          False            False
# 3                          False          False            False
# 4                          False          False            False
# ..                           ...            ...              ...
# 100                         True          False            False
# 101                        False          False            False
# 102                         True          False            False
# 103                         True          False            False
# 104                         True          False            False
#
#                               jobCardRequirementsModel jobLocationCity  \
# 0    {'additionalRequirementsCount': 0, 'requiremen...   Oklahoma City
# 1    {'additionalRequirementsCount': -2, 'requireme...       Tucumcari
# 2    {'additionalRequirementsCount': 0, 'requiremen...    Indianapolis
# 3    {'additionalRequirementsCount': 0, 'requiremen...           Alamo
# 4    {'additionalRequirementsCount': 0, 'requiremen...            Mesa
# ..                                                 ...             ...
# 100  {'additionalRequirementsCount': 0, 'requiremen...        New York
# 101  {'additionalRequirementsCount': 0, 'requiremen...          Remote
# 102  {'additionalRequirementsCount': 0, 'requiremen...      Mount Hope
# 103  {'additionalRequirementsCount': 0, 'requiremen...        New York
# 104  {'additionalRequirementsCount': 0, 'requiremen...         Chicago
#
#     jobLocationState      jobTypes  locationCount  newJob  \
# 0                 OK            []              1   False
# 1                 NM            []              1   False
# 2                 IN            []              5    True
# 3                 TX            []              3   False
# 4                 AZ            []              1    True
# ..               ...           ...            ...     ...
# 100               NY            []              1   False
# 101              NaN  ['Contract']              1   False
# 102               OH            []              1   False
# 103               NY            []              1   False
# 104               IL            []              1   False
#
#                     normTitle  openInterviewsInterviewsOnTheSpot  \
# 0       Chief Quality Officer                              False
# 1     Chief Financial Officer                              False
# 2     Chief Operating Officer                              False
# 3     Chief Financial Officer                              False
# 4       Chief Quality Officer                              False
# ..                        ...                                ...
# 100   Chief Operating Officer                              False
# 101         Portfolio Manager                              False
# 102  Chief Technology Officer                              False
# 103  Chief Technology Officer                              False
# 104  Chief Technology Officer                              False
#
#      openInterviewsJob  openInterviewsOffersOnTheSpot  openInterviewsPhoneJob  \
# 0                False                          False                   False
# 1                False                          False                   False
# 2                False                          False                   False
# 3                False                          False                   False
# 4                False                          False                   False
# ..                 ...                            ...                     ...
# 100              False                          False                   False
# 101              False                          False                   False
# 102              False                          False                   False
# 103              False                          False                   False
# 104              False                          False                   False
#
#      overrideIndeedApplyText        pubDate  \
# 0                       True  1674540000000
# 1                       True  1695618000000
# 2                       True  1699250400000
# 3                       True  1698037200000
# 4                       True  1699596000000
# ..                       ...            ...
# 100                     True  1690347600000
# 101                     True  1695013200000
# 102                     True  1698728400000
# 103                     True  1697000400000
# 104                     True  1698296400000
#
#                                     rankingScoresModel  remoteLocation  \
# 0    {'bid': 516053, 'eApply': 0.0009227544, 'eQual...           False
# 1    {'bid': 364162, 'eApply': 0.00069609965, 'eQua...           False
# 2    {'bid': 76882, 'eApply': 0.0010758947, 'eQuali...           False
# 3    {'bid': 41996, 'eApply': 0.0022876249, 'eQuali...           False
# 4    {'bid': 47195, 'eApply': 0.007137305, 'eQualif...           False
# ..                                                 ...             ...
# 100  {'bid': 0, 'eApply': 0.0035462398, 'eQualified...           False
# 101  {'bid': 0, 'eApply': 0.0018838488, 'eQualified...            True
# 102  {'bid': 366000, 'eApply': 0.0022818476, 'eQual...           False
# 103  {'bid': 0, 'eApply': 0.003098441, 'eQualified'...           False
# 104  {'bid': 5571, 'eApply': 0.0028044933, 'eQualif...           False
#
#      resumeMatch                                      salarySnippet  \
# 0          False  {'currency': 'USD', 'salaryTextFormatted': False}
# 1          False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# 2          False  {'currency': 'USD', 'salaryTextFormatted': False}
# 3          False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# 4          False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# ..           ...                                                ...
# 100        False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# 101        False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# 102        False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# 103        False  {'currency': 'USD', 'salaryTextFormatted': Fal...
# 104        False  {'currency': 'USD', 'salaryTextFormatted': Fal...
#
#               screenerQuestionsURL  showAttainabilityBadge  showCommutePromo  \
# 0    iq://10c7fa972cfad66fc91d?v=1                   False             False
# 1    iq://d37113be08ab5ba23aef?v=1                   False             False
# 2    iq://655a2395ef8200b4b70f?v=1                   False             False
# 3                              NaN                   False             False
# 4                              NaN                   False             False
# ..                             ...                     ...               ...
# 100                            NaN                   False             False
# 101                            NaN                   False             False
# 102                            NaN                   False             False
# 103                            NaN                   False             False
# 104                            NaN                   False             False
#
#      showEarlyApply  showJobType  showRelativeDate  showSponsoredLabel  \
# 0             False        False              True               False
# 1             False        False              True               False
# 2             False        False              True               False
# 3             False        False              True               False
# 4             False        False              True               False
# ..              ...          ...               ...                 ...
# 100           False        False              True               False
# 101           False        False              True               False
# 102           False        False              True               False
# 103           False        False              True               False
# 104           False        False              True               False
#
#      showStrongerAppliedLabel  smartFillEnabled  smbD2iEnabled  \
# 0                       False             False          False
# 1                       False             False          False
# 2                       False             False          False
# 3                       False             False          False
# 4                       False             False          False
# ..                        ...               ...            ...
# 100                     False             False          False
# 101                     False             False          False
# 102                     False             False          False
# 103                     False             False          False
# 104                     False             False          False
#
#                                                snippet  sponsored  \
# 0    This position is responsible for facilitating ...       True
# 1    FULL-TIME/ PART-TIME: Full Time.\n Mesalands C...       True
# 2    Our team plays a vital role in the recovery pr...       True
# 3    The Hospital Vice President Finance will be re...       True
# 4    The Nurse Chief Quality Officer will be respon...       True
# ..                                                 ...        ...
# 100  Coach product managers and team members on ear...      False
# 101  Backblaze makes storing and using data astonis...      False
# 102  Lead Innovation Engineering team that will res...      False
# 103  Partner across the organization to develop a l...      False
# 104  Excellent interpersonal skills that represents...       True
#
#     taxoAttributes  taxoAttributesDisplayLimit taxoLogAttributes  \
# 0               []                           3                []
# 1               []                           3                []
# 2               []                           3                []
# 3               []                           3                []
# 4               []                           3                []
# ..             ...                         ...               ...
# 100             []                           3                []
# 101             []                           3                []
# 102             []                           3                []
# 103             []                           3                []
# 104             []                           3                []
#
#                                     taxonomyAttributes  \
# 0    [{'attributes': [], 'label': 'dynamic-attribut...
# 1    [{'attributes': [], 'label': 'dynamic-attribut...
# 2    [{'attributes': [{'label': 'Flexible schedule'...
# 3    [{'attributes': [], 'label': 'dynamic-attribut...
# 4    [{'attributes': [{'label': 'Bonus opportunitie...
# ..                                                 ...
# 100  [{'attributes': [{'label': 'Bonus opportunitie...
# 101  [{'attributes': [], 'label': 'dynamic-attribut...
# 102  [{'attributes': [], 'label': 'dynamic-attribut...
# 103  [{'attributes': [{'label': 'Bonus opportunitie...
# 104  [{'attributes': [], 'label': 'dynamic-attribut...
#
#                                     thirdPartyApplyUrl  \
# 0    http://www.indeed.com//applystart?jk=4d8992b61...
# 1    http://www.indeed.com//applystart?jk=808042413...
# 2    http://www.indeed.com//applystart?jk=662ea1d8f...
# 3    http://www.indeed.com//applystart?jk=c4fe7497a...
# 4    http://www.indeed.com//applystart?jk=94244e37c...
# ..                                                 ...
# 100  http://www.indeed.com//applystart?jk=2036d50c7...
# 101  http://www.indeed.com//applystart?jk=59b98c762...
# 102  http://www.indeed.com//applystart?jk=e8dfd413b...
# 103  http://www.indeed.com//applystart?jk=0fabc0b02...
# 104  http://www.indeed.com//applystart?jk=295a957be...
#
#                                                  title translatedAttributes  \
# 0    system chief quality officer regulatory compli...                   []
# 1                              chief financial officer                   []
# 2       chief operating officer chief clinical officer                   []
# 3                     hospital chief financial officer                   []
# 4                          nurse chief quality officer                   []
# ..                                                 ...                  ...
# 100        product organizational coach cto coo office                   []
# 101          portfolio manager pmo office cto contract                   []
# 102                           chief technology officer                   []
# 103               applied researcher search cto office                   []
# 104                                         deputy cto                   []
#
#     translatedCmiJobTags                 truncatedCompany  urgentlyHiring  \
# 0                     []               Community Hospital           False
# 1                     []      Mesalands Community College            True
# 2                     []     Cornerstone Healthcare Group            True
# 3                     []  Clinical Management Consultants           False
# 4                     []  Clinical Management Consultants           False
# ..                   ...                              ...             ...
# 100             ['賞与あり']                        Bloomberg           False
# 101             ['完全在宅']                        Backblaze           False
# 102                   []        Overhead Door Corporation           False
# 103             ['賞与あり']                        Bloomberg           False
# 104                   []                     Michael Page           False
#
#      vjFeaturedEmployerCandidate  \
# 0                          False
# 1                          False
# 2                          False
# 3                          False
# 4                          False
# ..                           ...
# 100                        False
# 101                        False
# 102                        False
# 103                        False
# 104                        False
#
#                                         jobDescription  \
# 0    updated pay scales august looking experienced ...
# 1    mesalands community college position announcem...
# 2    scionhealth opportunity chief operating office...
# 3    beloved hospital organization south texas acti...
# 4    outstanding medical center searching strong nu...
# ..                                                 ...
# 100  bloomberg cto office future looking technical ...
# 101  backblaze backblaze makes storing data astonis...
# 102  position position reports genie company presid...
# 103  bloomberg cto office future looking technical ...
# 104  person improve manage firms information techno...
#
#                                        extractedSalary  \
# 0                                                  NaN
# 1       {'max': 90000, 'min': 65000, 'type': 'yearly'}
# 2                                                  NaN
# 3     {'max': 276569, 'min': 250897, 'type': 'yearly'}
# 4           {'max': 115, 'min': 115, 'type': 'hourly'}
# ..                                                 ...
# 100   {'max': 210000, 'min': 145000, 'type': 'yearly'}
# 101   {'max': 150000, 'min': 105000, 'type': 'yearly'}
# 102  {'max': 97510.66, 'min': 80968.68, 'type': 'ye...
# 103   {'max': 330000, 'min': 240000, 'type': 'yearly'}
# 104   {'max': 300000, 'min': 250000, 'type': 'yearly'}
#
#                      searched_title
# 0        Chief Intelligence Officer
# 1        Chief Intelligence Officer
# 2        Chief Intelligence Officer
# 3        Chief Intelligence Officer
# 4        Chief Intelligence Officer
# ..                              ...
# 100  Chief Technology Officer (CTO)
# 101  Chief Technology Officer (CTO)
# 102  Chief Technology Officer (CTO)
# 103  Chief Technology Officer (CTO)
# 104  Chief Technology Officer (CTO)
#
# [7619 rows x 68 columns]

# %%
## Lemmatizer stopword removal modules 




# Ensure you have the necessary NLTK tokens downloaded
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')


# Initialize the lemmatizer and stopwords
lemmatizer = WordNetLemmatizer()
stop_words = set(stopwords.words('english'))

# Load the spaCy model
nlp = spacy.load('en_core_web_md')

def preprocess_text_spacy(text):
    # Use spaCy's pipeline for processing the passed text
    doc = nlp(text)
    preprocessed_text= []
    # Return a preprocessed version of the text (for instance, lemmatized, lowercased, no stop words/punctuations)
    for token in doc:
        # Skip stop words and punctuation
        if token.is_stop or token.is_punct or token.is_space:
            continue
        # Special case for 'data' to keep it in plural form
        if token.lemma_ == 'datum':
            preprocessed_text.append('data')
        else:
            preprocessed_text.append(token.text.lower())

    return ' '.join(preprocessed_text)


# Function to clean and lemmatize job title text
def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z]', ' ', text)
    words = nltk.word_tokenize(text)
    #words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]
    words = [word for word in words if word not in stop_words]
    return ' '.join(words)

def clean_lem_stop(df,column_name):
    df[column_name] = df[column_name].apply(preprocess_text_spacy)
    df[column_name] = df[column_name].apply(clean_text)
    return df
# Out:
# [nltk_data] Downloading package punkt to /Users/nyzy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /Users/nyzy/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to /Users/nyzy/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
## clean skills dataset 

#clean skills dataset 

skills = pd.DataFrame(df_s[df_s["Unnamed: 5"].notna()]["Unnamed: 5"].unique())
skills.columns=["skills"]
#skills["skills"] = skills["skills"].apply(preprocess_text_spacy)
skills["skills"] = skills["skills"].apply(clean_text)
skills_list = skills["skills"].tolist()
skills_list.append('python')
skills_list.append('python programming')
skills_list.append('statistical')
skills_list.append("r programming")

for ach in ["docker",
 "neural network","matlab","google bard ai","ai governance","machine learning","tensorflow","computer vision","prompts","generate prompts","generative","generative ai","nlp","natural language processing","langchain",
 "pytorch","llm","scala","opencv"]:
    skills_list.append(ach)

# %%
df_s_skills_list = pd.DataFrame(skills_list, columns=['skills_list'])

df_s_skills_list.to_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/skills_dataset/skills_list_df.csv")

# %%
## filter the data for validation
#df_j = df_j[:100]
#df_c = df_c[:100]

# %%
## clean jobs dataset 

def clean_job_df(df):
    df = clean_lem_stop(df,"title")
    df = clean_lem_stop(df,"jobDescription")
    job_descriptions = df_j["jobDescription"].tolist()
    return df,job_descriptions

df_j_cleaned,job_descriptions = clean_job_df(df_j)

columns_of_interest = ['company',
 'companyRating',
 'companyReviewCount',
 'displayTitle',
 'employerAssistEnabled',
 'employerResponsive',
 'extractedSalary',
 'featuredEmployer',
 'featuredEmployerCandidate',
 'formattedLocation',
 'formattedRelativeTime',
 'highVolumeHiringModel',
 'hiringEventJob',
 'indeedApplyEnabled',
 'indeedApplyable',
 'isJobVisited',
 'isMobileThirdPartyApplyable',
 'isNoResumeJob',
 'isSubsidiaryJob',
 'jobCardRequirementsModel',
 'jobLocationCity',
 'jobLocationState',
 'locationCount',
 'newJob',
 'normTitle',
 'openInterviewsInterviewsOnTheSpot',
 'openInterviewsJob',
 'openInterviewsOffersOnTheSpot',
 'openInterviewsPhoneJob',
 'overrideIndeedApplyText',
 'remoteLocation',
 'resumeMatch',
 'salarySnippet',
 'showAttainabilityBadge',
 'showCommutePromo',
 'showEarlyApply',
 'showJobType',
 'showRelativeDate',
 'showSponsoredLabel',
 'showStrongerAppliedLabel',
 'smartFillEnabled',
 'smbD2iEnabled',
 'snippet',
 'sponsored',
 'title',
 'truncatedCompany',
 'urgentlyHiring',
 'vjFeaturedEmployerCandidate',
 'jobDescription','searched_title']


import ast 
import numpy as np
def salary_to_dict(row):
    if pd.isna(row):
        # Return a dictionary with NaN values if the row is NaN
        return {'max': np.nan, 'min': np.nan, 'type': np.nan}
    elif isinstance(row, dict):
        # Return the row as is if it's already a dictionary
        return row
    else:
        # If the row is a string representation of a dictionary (assumed if not NaN or dict),
        # safely evaluate it to a dictionary here
        # Note: Be cautious with `eval`. Here it's mentioned for potential string to dict conversion.
        # In a secure context, confirm the string format and consider `ast.literal_eval` instead.
        try:
            # Convert string to dictionary safely
            dict_row = eval(row)
            return dict_row if isinstance(dict_row, dict) else {'max': np.nan, 'min': np.nan, 'type': np.nan}
        except:
            # In case of error during eval, return NaN values
            return {'max': np.nan, 'min': np.nan, 'type': np.nan}

# Apply the function to each row of the 'extractedSalary' column
salary_dicts = df_j_cleaned['extractedSalary'].apply(salary_to_dict)
# Now that we have a series of dictionaries, use `json_normalize` to create a DataFrame
salary_df = pd.json_normalize(salary_dicts)

# Concatenate the new DataFrame with the original one
df_j_cleaned = pd.concat([df_j_cleaned.drop('extractedSalary', axis=1).reset_index(), salary_df], axis=1)

#df["extractedSalary"]=df["extractedSalary"].astype(str)
#df["extractedSalary"]=df['extractedSalary'].apply(ast.literal_eval)

import ast 
import numpy as np
def salary_snippet_to_dict(row):
    if pd.isna(row):
        # Return a dictionary with NaN values if the row is NaN
        return {'currency': np.nan, 'salaryTextFormatted': np.nan, 'source': np.nan,'text':np.nan}
    elif isinstance(row, dict):
        # Return the row as is if it's already a dictionary
        return row
    else:
        # If the row is a string representation of a dictionary (assumed if not NaN or dict),
        # safely evaluate it to a dictionary here
        # Note: Be cautious with `eval`. Here it's mentioned for potential string to dict conversion.
        # In a secure context, confirm the string format and consider `ast.literal_eval` instead.
        try:
            # Convert string to dictionary safely
            dict_row = eval(row)
            return dict_row if isinstance(dict_row, dict) else {'max': np.nan, 'min': np.nan, 'type': np.nan}
        except:
            # In case of error during eval, return NaN values
            return {'currency': np.nan, 'salaryTextFormatted': np.nan, 'source': np.nan,'text':np.nan}

# Apply the function to each row of the 'extractedSalary' column
salary_snippet_dicts = df_j_cleaned['salarySnippet'].apply(salary_snippet_to_dict)
# Now that we have a series of dictionaries, use `json_normalize` to create a DataFrame
salary_snippet_df = pd.json_normalize(salary_snippet_dicts)

# Concatenate the new DataFrame with the original one
df_j_cleaned = pd.concat([df_j_cleaned.drop('salarySnippet', axis=1).reset_index(), salary_snippet_df], axis=1)

#df["extractedSalary"]=df["extractedSalary"].astype(str)
#df["extractedSalary"]=df['extractedSalary'].apply(ast.literal_eval)

# %%
## phrase matcher model to extract skills from job description 



#phrase matcher model for skills

import spacy
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
from spacy.util import filter_spans

def phrase_matcher_model(description,skills_list):
    nlp = spacy.load("en_core_web_md")  # Load the model
    matcher = PhraseMatcher(nlp.vocab, attr="LOWER")  # Create the matcher object

    # Assuming 'skills_list' is a list of skills, and 'job_descriptions' is a list containing job descriptions

    # Add patterns to the matcher. Patterns are made by converting each skill string into a Doc object
    patterns = [nlp.make_doc(skill) for skill in skills_list]
    matcher.add("Skills", patterns)

    # Process the job description to create a Spacy Doc
    doc = nlp(description)

    # Match the patterns to the doc
    matches = matcher(doc)

    # Create Span objects for the matched sequences
    spans = [Span(doc, start, end, label="SKILL") for match_id, start, end in matches]

    # Filter the spans to remove overlaps
    filtered_spans = filter_spans(spans)

    # Now you can create new entities in the doc using the filtered spans
    doc.ents = filtered_spans  # Overwrite or append to doc.ents with the non-overlapping skill entities
    entities_extracted = []
    # Print the entities in the document
    for ent in doc.ents:
        entities_extracted.append(ent.text)
    '''
    for each in matches:
        #print(each)
        if each.lower_ == "statistical":
            for skills_identify in skills_list:
                if each.lower_ in skills_identify:
                    #print(skills_identify)
                    entities_extracted.append(skills_identify)
    '''
    return set(entities_extracted)

df_j_cleaned["skills_tagged"]=df_j_cleaned["jobDescription"].apply(lambda x:phrase_matcher_model(x,skills_list))

# %%
df_j_cleaned
# Out:
#       Unnamed: 0                          company  \
# 0              0               Community Hospital
# 1              1      Mesalands Community College
# 2              2     Cornerstone Healthcare Group
# 3              3  Clinical Management Consultants
# 4              4  Clinical Management Consultants
# ...          ...                              ...
# 7614        7614                        Bloomberg
# 7615        7615                        Backblaze
# 7616        7616        Overhead Door Corporation
# 7617        7617                        Bloomberg
# 7618        7618                     Michael Page
#
#                      truncatedCompany  companyRating  companyReviewCount  \
# 0                  Community Hospital            3.1                39.0
# 1         Mesalands Community College            3.8                14.0
# 2        Cornerstone Healthcare Group            3.3              5192.0
# 3     Clinical Management Consultants            4.2                13.0
# 4     Clinical Management Consultants            4.2                13.0
# ...                               ...            ...                 ...
# 7614                        Bloomberg            3.9               952.0
# 7615                        Backblaze            3.5                 2.0
# 7616        Overhead Door Corporation            3.2               386.0
# 7617                        Bloomberg            3.9               952.0
# 7618                     Michael Page            3.7               512.0
#
#                       searched_title  \
# 0         Chief Intelligence Officer
# 1         Chief Intelligence Officer
# 2         Chief Intelligence Officer
# 3         Chief Intelligence Officer
# 4         Chief Intelligence Officer
# ...                              ...
# 7614  Chief Technology Officer (CTO)
# 7615  Chief Technology Officer (CTO)
# 7616  Chief Technology Officer (CTO)
# 7617  Chief Technology Officer (CTO)
# 7618  Chief Technology Officer (CTO)
#
#                                                   title  \
# 0     system chief quality officer regulatory compli...
# 1                               chief financial officer
# 2        chief operating officer chief clinical officer
# 3                      hospital chief financial officer
# 4                           nurse chief quality officer
# ...                                                 ...
# 7614        product organizational coach cto coo office
# 7615          portfolio manager pmo office cto contract
# 7616                           chief technology officer
# 7617               applied researcher search cto office
# 7618                                         deputy cto
#
#                  title_cleaned                 normTitle            min  \
# 0                    unmatched     Chief Quality Officer  101224.267633
# 1                    unmatched   Chief Financial Officer   65000.000000
# 2                    unmatched   Chief Operating Officer  101224.267633
# 3                    unmatched   Chief Financial Officer  250897.000000
# 4                    unmatched     Chief Quality Officer  239200.000000
# ...                        ...                       ...            ...
# 7614                 unmatched   Chief Operating Officer  145000.000000
# 7615                 unmatched         Portfolio Manager  105000.000000
# 7616  chief technology officer  Chief Technology Officer   80968.680000
# 7617  chief technology officer  Chief Technology Officer  240000.000000
# 7618  chief technology officer  Chief Technology Officer  250000.000000
#
#                 max    type  \
# 0     109678.007728  yearly
# 1      75000.000000  yearly
# 2     109678.007728  yearly
# 3     260897.000000  yearly
# 4     260000.000000  yearly
# ...             ...     ...
# 7614  155000.000000  yearly
# 7615  115000.000000  yearly
# 7616   90968.680000  yearly
# 7617  250000.000000  yearly
# 7618  260000.000000  yearly
#
#                                                 snippet  \
# 0     This position is responsible for facilitating ...
# 1     FULL-TIME/ PART-TIME: Full Time.\n Mesalands C...
# 2     Our team plays a vital role in the recovery pr...
# 3     The Hospital Vice President Finance will be re...
# 4     The Nurse Chief Quality Officer will be respon...
# ...                                                 ...
# 7614  Coach product managers and team members on ear...
# 7615  Backblaze makes storing and using data astonis...
# 7616  Lead Innovation Engineering team that will res...
# 7617  Partner across the organization to develop a l...
# 7618  Excellent interpersonal skills that represents...
#
#                                          jobDescription  \
# 0     updated pay scales august looking experienced ...
# 1     mesalands community college position announcem...
# 2     scionhealth opportunity chief operating office...
# 3     beloved hospital organization south texas acti...
# 4     outstanding medical center searching strong nu...
# ...                                                 ...
# 7614  bloomberg cto office future looking technical ...
# 7615  backblaze backblaze makes storing data astonis...
# 7616  position position reports genie company presid...
# 7617  bloomberg cto office future looking technical ...
# 7618  person improve manage firms information techno...
#
#                                           skills_tagged  normalized_min  \
# 0                                                 set()       -0.168995
# 1                                   {'applied science'}       -0.919509
# 2                                                 set()       -0.168995
# 3                                                 {'c'}        2.932003
# 4                                                 set()        2.689659
# ...                                                 ...             ...
# 7614                                   {'data centers'}        0.737973
# 7615            {'cloud operations', 'problem solving'}       -0.090768
# 7616                           {'cloud infrastructure'}       -0.588661
# 7617  {'deep learning', 'cloud computing', 'natural ...        2.706234
# 7618                          {'business requirements'}        2.913419
#
#       normalized_max
# 0          -0.204351
# 1          -0.916695
# 2          -0.204351
# 3           2.901938
# 4           2.883512
# ...              ...
# 7614        0.726638
# 7615       -0.095028
# 7616       -0.588671
# 7617        2.678095
# 7618        2.883512
#
# [7619 rows x 17 columns]

# %%
## clean job titles using job progression dictionary and declare set of properly defined titles  


#job progression dictionary
# Define the original dictionary provided by the user

Job_progression_dictionary =  {
"Junior Data Analyst" : ["Data Analyst", "Senior Data Analyst", "Data Engineer", "Senior Data Engineer", "Lead Data Engineer", "Data Architect", "Data Manager", "Director of Analytics", "Chief Data Officer"],
"Junior Data Scientist" : ["Data Scientist", "Senior Data Scientist", "Lead Data Scientist", "Principal Data Scientist", "Data Science Manager", "Director of Data Science", "Vice President of Data Science", "Chief Data Scientist"],
"Junior Data Engineer" : ["Data Engineer", "Senior Data Engineer", "Data Pipeline Architect", "Data Engineering Manager", "Director of Data Engineering", "Chief Technology Officer (CTO)"],
"Business Intelligence Analyst" : ["Senior Business Intelligence Analyst", "Business Intelligence Manager", "Director of Business Intelligence", "Vice President of Business Intelligence", "Chief Intelligence Officer"],
"Machine Learning Engineer" : ["Senior Machine Learning Engineer", "Machine Learning Architect", "Machine Learning Manager", "Head of Machine Learning", "Chief AI Officer"],
"Data Analyst" : ["Data Engineer", "Senior Data Engineer", "Data Architect", "Senior Data Architect", "Enterprise Architect", "Chief Technology Officer (CTO)"],
"Data Analyst" : ["Big Data Engineer", "Senior Big Data Engineer", "Big Data Architect", "Head of Big Data", "Director of Data Engineering", "Chief Information Officer (CIO)"],
"Junior AI Developer" : ["AI Developer", "Senior AI Developer", "AI Architect", "AI Project Manager", "Head of AI", "Chief AI Officer"],
"Junior DBA" : ["Mid-level DBA", "Senior DBA", "Database Manager", "Data Architect", "Director of Database Management", "Chief Information Officer"],
"Junior Statistician" : ["Statistician" , "Senior Statistician", "Quantitative Analyst", "Senior Quantitative Analyst", "Quantitative Research Manager", "Director of Quantitative Research"],
"Junior Business Analyst" : ["Business Analyst", "Senior Business Analyst", "Business Analysis Manager", "Business Intelligence Analyst", "Director of Business Analysis", "Chief Strategy Officer"],
"Research Assistant" : ["Research Analyst", "Research Scientist", "Senior Research Scientist", "Principal Scientist", "Director of Research", "Chief Science Officer"],
"Data Analyst" : ["Product Analyst", "Data Product Manager", "Senior Data Product Manager", "Director of Product Management", "Vice President of Product", "Chief Product Officer"]
}

original_dict = {
    "Junior Data Analyst": ["Data Analyst", "Senior Data Analyst", "Data Engineer", "Senior Data Engineer", 
                            "Lead Data Engineer", "Data Architect", "Data Manager", "Director of Analytics", 
                            "Chief Data Officer"],
    "Junior Data Scientist": ["Data Scientist", "Senior Data Scientist", "Lead Data Scientist", 
                              "Principal Data Scientist", "Data Science Manager", "Director of Data Science", 
                              "Vice President of Data Science", "Chief Data Scientist"],
    "Junior Data Engineer": ["Data Engineer", "Senior Data Engineer", "Data Pipeline Architect", 
                             "Data Engineering Manager", "Director of Data Engineering", "Chief Technology Officer"],
    "Business Intelligence Analyst": ["Senior Business Intelligence Analyst", "Business Intelligence Manager", 
                                      "Director of Business Intelligence", "Vice President of Business Intelligence", 
                                      "Chief Intelligence Officer"],
    "Machine Learning Engineer": ["Senior Machine Learning Engineer", "Machine Learning Architect", 
                                  "Machine Learning Manager", "Head of Machine Learning", "Chief AI Officer"],
    "Junior AI Developer": ["AI Developer", "Senior AI Developer", "AI Architect", "AI Project Manager", 
                            "Head of AI", "Chief AI Officer"],
    "Junior DataBase Administrator": ["DataBase Administrator", "Senior DataBase Administrator", "Database Manager", "Data Architect", "Director of Database Management", 
                   "Chief Information Officer"],
    "Junior Statistician": ["Statistician", "Senior Statistician", "Quantitative Analyst", "Senior Quantitative Analyst", 
                            "Quantitative Research Manager", "Director of Quantitative Research"],
    "Junior Business Analyst": ["Business Analyst", "Senior Business Analyst", "Business Analysis Manager", 
                                "Business Intelligence Analyst", "Director of Business Analysis", "Chief Strategy Officer"],
    "Research Assistant": ["Research Analyst", "Research Scientist", "Senior Research Scientist", "Principal Scientist", 
                           "Director of Research", "Chief Science Officer"],
    # Multiple entries for Data Analyst have been combined to include all unique progressions
    "Data Analyst": ["Data Engineer", "Senior Data Engineer", "Lead Data Engineer", "Data Architect", 
                     "Senior Data Architect", "Enterprise Architect", "Product Analyst", "Data Product Manager", 
                     "Senior Data Product Manager", "Director of Product Management", "Vice President of Product", 
                     "Chief Product Officer", "Big Data Engineer", "Senior Big Data Engineer", "Big Data Architect", 
                     "Head of Big Data", "Director of Data Engineering", "Chief Information Officer"]
}

# Define lateral moves for the given roles
lateral_moves = {
    "Data Analyst": ["Business Intelligence Analyst", "Machine Learning Engineer"],
    "Data Scientist": ["Data Engineer", "AI Developer"],
    "Data Engineer": ["Machine Learning Engineer", "Big Data Engineer"],
    "Business Intelligence Analyst": ["Data Analyst", "Data Scientist"],
    "Machine Learning Engineer": ["Data Scientist", "AI Developer"],
    "AI Developer": ["Machine Learning Engineer", "Data Engineer"],
    "Data Base Administrator": ["Data Engineer", "Data Analyst"],
    "Statistician": ["Data Analyst", "Data Scientist"],
    "Business Analyst": ["Data Analyst", "Business Intelligence Analyst"],
    "Research Analyst": ["Data Scientist", "Statistician"]
}

# Since we want to include lateral moves for each value in the original dictionary, 
# we will create a function that merges the direct progressions and lateral moves into one list.

# Function to merge progression and lateral moves
def merge_progression_and_lateral_moves(direct_progression, lateral_move_titles):
    # Start with direct progression
    full_progression = direct_progression.copy()
    
    # Add lateral moves for each title in the direct progression if they exist
    for title in direct_progression:
        lateral_titles = lateral_moves.get(title, [])
        for lateral_title in lateral_titles:
            if lateral_title not in full_progression:  # Avoid duplicates
                full_progression.append(lateral_title)
    
    return full_progression

# Function to build a full job progression dictionary for each title
def build_full_progression_dict(original_dict, lateral_moves):
    full_progression_dict = {}
    
    # Iterate over each starting job title
    for start_title, progression in original_dict.items():
        # Get the full progression for the starting title
        full_progression = merge_progression_and_lateral_moves(progression, lateral_moves)
        
        # Add the full progression to the dictionary for the starting title
        full_progression_dict[start_title] = full_progression
        
        # Now iterate over each job within the progression to build their own progression paths
        for i, title in enumerate(progression):
            if title not in full_progression_dict:  # Only add if it doesn't already exist to avoid overwriting
                # Get the progression for this title (which is the rest of the list after this title)
                next_progression = merge_progression_and_lateral_moves(progression[i + 1:], lateral_moves)
                full_progression_dict[title] = next_progression
    
    return full_progression_dict

# Building the full job progression dictionary
full_job_progression_dict = build_full_progression_dict(original_dict, lateral_moves)

# Sorting the dictionary for better readability
sorted_full_job_progression_dict = {k: full_job_progression_dict[k] for k in sorted(full_job_progression_dict)}


unique_job_title_full = set()
for key,value in Job_progression_dictionary.items():
    unique_job_title_full.add(key)
    for each in value:
        unique_job_title_full.add(each)


unique_job_title = set()
for key,value in sorted_full_job_progression_dict.items():
    unique_job_title.add(key)
    for each in value:
        unique_job_title.add(each)

unique_job_title.difference(unique_job_title_full)

sorted_full_job_progression_dict

sorted_full_job_progression_dict_lower={}
for k,v in sorted_full_job_progression_dict.items():
    sorted_full_job_progression_dict_lower[k.lower()]=[each.lower() for each in v]

sorted_full_job_progression_dict_lower
# Out:
# {'ai architect': ['ai project manager', 'head of ai', 'chief ai officer'],
#  'ai developer': ['senior ai developer',
#   'ai architect',
#   'ai project manager',
#   'head of ai',
#   'chief ai officer'],
#  'ai project manager': ['head of ai', 'chief ai officer'],
#  'big data architect': ['head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'big data engineer': ['senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'business analysis manager': ['business intelligence analyst',
#   'director of business analysis',
#   'chief strategy officer',
#   'data analyst',
#   'data scientist'],
#  'business analyst': ['senior business analyst',
#   'business analysis manager',
#   'business intelligence analyst',
#   'director of business analysis',
#   'chief strategy officer',
#   'data analyst',
#   'data scientist'],
#  'business intelligence analyst': ['senior business intelligence analyst',
#   'business intelligence manager',
#   'director of business intelligence',
#   'vice president of business intelligence',
#   'chief intelligence officer'],
#  'business intelligence manager': ['director of business intelligence',
#   'vice president of business intelligence',
#   'chief intelligence officer'],
#  'chief ai officer': [],
#  'chief data officer': [],
#  'chief data scientist': [],
#  'chief information officer': [],
#  'chief intelligence officer': [],
#  'chief product officer': ['big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'chief science officer': [],
#  'chief strategy officer': [],
#  'chief technology officer': [],
#  'data analyst': ['data engineer',
#   'senior data engineer',
#   'lead data engineer',
#   'data architect',
#   'senior data architect',
#   'enterprise architect',
#   'product analyst',
#   'data product manager',
#   'senior data product manager',
#   'director of product management',
#   'vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer',
#   'machine learning engineer'],
#  'data architect': ['data manager',
#   'director of analytics',
#   'chief data officer'],
#  'data engineer': ['senior data engineer',
#   'lead data engineer',
#   'data architect',
#   'data manager',
#   'director of analytics',
#   'chief data officer'],
#  'data engineering manager': ['director of data engineering',
#   'chief technology officer'],
#  'data manager': ['director of analytics', 'chief data officer'],
#  'data pipeline architect': ['data engineering manager',
#   'director of data engineering',
#   'chief technology officer'],
#  'data product manager': ['senior data product manager',
#   'director of product management',
#   'vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'data science manager': ['director of data science',
#   'vice president of data science',
#   'chief data scientist'],
#  'data scientist': ['senior data scientist',
#   'lead data scientist',
#   'principal data scientist',
#   'data science manager',
#   'director of data science',
#   'vice president of data science',
#   'chief data scientist'],
#  'database administrator': ['senior database administrator',
#   'database manager',
#   'data architect',
#   'director of database management',
#   'chief information officer'],
#  'database manager': ['data architect',
#   'director of database management',
#   'chief information officer'],
#  'director of analytics': ['chief data officer'],
#  'director of business analysis': ['chief strategy officer'],
#  'director of business intelligence': ['vice president of business intelligence',
#   'chief intelligence officer'],
#  'director of data engineering': ['chief technology officer'],
#  'director of data science': ['vice president of data science',
#   'chief data scientist'],
#  'director of database management': ['chief information officer'],
#  'director of product management': ['vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'director of quantitative research': [],
#  'director of research': ['chief science officer'],
#  'enterprise architect': ['product analyst',
#   'data product manager',
#   'senior data product manager',
#   'director of product management',
#   'vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'head of ai': ['chief ai officer'],
#  'head of big data': ['director of data engineering',
#   'chief information officer'],
#  'head of machine learning': ['chief ai officer'],
#  'junior ai developer': ['ai developer',
#   'senior ai developer',
#   'ai architect',
#   'ai project manager',
#   'head of ai',
#   'chief ai officer',
#   'machine learning engineer',
#   'data engineer'],
#  'junior business analyst': ['business analyst',
#   'senior business analyst',
#   'business analysis manager',
#   'business intelligence analyst',
#   'director of business analysis',
#   'chief strategy officer',
#   'data analyst',
#   'data scientist'],
#  'junior data analyst': ['data analyst',
#   'senior data analyst',
#   'data engineer',
#   'senior data engineer',
#   'lead data engineer',
#   'data architect',
#   'data manager',
#   'director of analytics',
#   'chief data officer',
#   'business intelligence analyst',
#   'machine learning engineer',
#   'big data engineer'],
#  'junior data engineer': ['data engineer',
#   'senior data engineer',
#   'data pipeline architect',
#   'data engineering manager',
#   'director of data engineering',
#   'chief technology officer',
#   'machine learning engineer',
#   'big data engineer'],
#  'junior data scientist': ['data scientist',
#   'senior data scientist',
#   'lead data scientist',
#   'principal data scientist',
#   'data science manager',
#   'director of data science',
#   'vice president of data science',
#   'chief data scientist',
#   'data engineer',
#   'ai developer'],
#  'junior database administrator': ['database administrator',
#   'senior database administrator',
#   'database manager',
#   'data architect',
#   'director of database management',
#   'chief information officer'],
#  'junior statistician': ['statistician',
#   'senior statistician',
#   'quantitative analyst',
#   'senior quantitative analyst',
#   'quantitative research manager',
#   'director of quantitative research',
#   'data analyst',
#   'data scientist'],
#  'lead data engineer': ['data architect',
#   'data manager',
#   'director of analytics',
#   'chief data officer'],
#  'lead data scientist': ['principal data scientist',
#   'data science manager',
#   'director of data science',
#   'vice president of data science',
#   'chief data scientist'],
#  'machine learning architect': ['machine learning manager',
#   'head of machine learning',
#   'chief ai officer'],
#  'machine learning engineer': ['senior machine learning engineer',
#   'machine learning architect',
#   'machine learning manager',
#   'head of machine learning',
#   'chief ai officer'],
#  'machine learning manager': ['head of machine learning', 'chief ai officer'],
#  'principal data scientist': ['data science manager',
#   'director of data science',
#   'vice president of data science',
#   'chief data scientist'],
#  'principal scientist': ['director of research', 'chief science officer'],
#  'product analyst': ['data product manager',
#   'senior data product manager',
#   'director of product management',
#   'vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'quantitative analyst': ['senior quantitative analyst',
#   'quantitative research manager',
#   'director of quantitative research'],
#  'quantitative research manager': ['director of quantitative research'],
#  'research analyst': ['research scientist',
#   'senior research scientist',
#   'principal scientist',
#   'director of research',
#   'chief science officer'],
#  'research assistant': ['research analyst',
#   'research scientist',
#   'senior research scientist',
#   'principal scientist',
#   'director of research',
#   'chief science officer',
#   'data scientist',
#   'statistician'],
#  'research scientist': ['senior research scientist',
#   'principal scientist',
#   'director of research',
#   'chief science officer'],
#  'senior ai developer': ['ai architect',
#   'ai project manager',
#   'head of ai',
#   'chief ai officer'],
#  'senior big data engineer': ['big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'senior business analyst': ['business analysis manager',
#   'business intelligence analyst',
#   'director of business analysis',
#   'chief strategy officer',
#   'data analyst',
#   'data scientist'],
#  'senior business intelligence analyst': ['business intelligence manager',
#   'director of business intelligence',
#   'vice president of business intelligence',
#   'chief intelligence officer'],
#  'senior data analyst': ['data engineer',
#   'senior data engineer',
#   'lead data engineer',
#   'data architect',
#   'data manager',
#   'director of analytics',
#   'chief data officer',
#   'machine learning engineer',
#   'big data engineer'],
#  'senior data architect': ['enterprise architect',
#   'product analyst',
#   'data product manager',
#   'senior data product manager',
#   'director of product management',
#   'vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'senior data engineer': ['lead data engineer',
#   'data architect',
#   'data manager',
#   'director of analytics',
#   'chief data officer'],
#  'senior data product manager': ['director of product management',
#   'vice president of product',
#   'chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer'],
#  'senior data scientist': ['lead data scientist',
#   'principal data scientist',
#   'data science manager',
#   'director of data science',
#   'vice president of data science',
#   'chief data scientist'],
#  'senior database administrator': ['database manager',
#   'data architect',
#   'director of database management',
#   'chief information officer'],
#  'senior machine learning engineer': ['machine learning architect',
#   'machine learning manager',
#   'head of machine learning',
#   'chief ai officer'],
#  'senior quantitative analyst': ['quantitative research manager',
#   'director of quantitative research'],
#  'senior research scientist': ['principal scientist',
#   'director of research',
#   'chief science officer'],
#  'senior statistician': ['quantitative analyst',
#   'senior quantitative analyst',
#   'quantitative research manager',
#   'director of quantitative research'],
#  'statistician': ['senior statistician',
#   'quantitative analyst',
#   'senior quantitative analyst',
#   'quantitative research manager',
#   'director of quantitative research'],
#  'vice president of business intelligence': ['chief intelligence officer'],
#  'vice president of data science': ['chief data scientist'],
#  'vice president of product': ['chief product officer',
#   'big data engineer',
#   'senior big data engineer',
#   'big data architect',
#   'head of big data',
#   'director of data engineering',
#   'chief information officer']}

# %%
import json
# Saving the jon progress dictionary to a JSON file
Job_progression_dictionary_file_path = "/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_progression_dictionary.json"

with open(Job_progression_dictionary_file_path, 'w') as json_file:
    json.dump(sorted_full_job_progression_dict_lower, json_file)

# %%
#clean job titles by fuzzy matching and normalizing against job preogression titles
import re
import numpy as np
from fuzzywuzzy import process
#base_job_titles = list(sorted_full_job_progression_dict.keys())  # Add any other base titles as necessary
#scraped_titles = df_j_cleaned["displayTitle"].unique().tolist()

# Function to normalize job titles
def normalize_title(title):
    # Lowercase and remove non-alphanumeric characters, replace with spaces
    title = re.sub(r'[^a-z0-9]', ' ', title.lower())
    # Remove extra whitespace
    title = re.sub(r'\s+', ' ', title).strip()

        # Remove common prefixes/suffixes
    #title = re.sub(r'\b(senior|junior|associate|expert|technical|lead|l\d+)\b', '', title)
    title = re.sub(r'\b(sr|senior|expert|technical|lead|l\d+)\b', 'Senior', title)
    title = re.sub(r'\b(vp|vice president|l\d+)\b', 'Senior', title)
    title = re.sub(r'\b(III|6|5|4|3|l\d+)\b', 'Senior', title)
    # Replace specific terms with standardized equivalents
    title = re.sub(r'\b(sr\.?|senior)\b', 'senior', title)  # Replace 'sr' or 'senior' with 'senior'
    title = re.sub(r'\b(jr\.?|junior)\b', 'junior', title) 

    # Convert to lower case and remove special characters
    title = re.sub(r'[^a-z\s]', '', title.lower())

    # Strip extra whitespace
    title = re.sub(r'\s+', ' ', title).strip()
    return title

# Create a set of base job titles from your job progression dictionary
base_job_titles = set()
for titles_list in sorted_full_job_progression_dict.values():
    for title in titles_list:
        base_job_titles.add(normalize_title(title))  # Add the normalized base title



# Function to find the best matching title from the base job titles
def match_title_to_base(scraped_title, base_job_titles):
    # Normalize the scraped job title
    normalized_title = normalize_title(scraped_title)
    # Check if the normalized title exactly matches one of the base job titles
    if normalized_title in base_job_titles:
        return normalized_title  # Return the matching base title
    
    # Partial match checking - longer base titles are checked first to match more specific job titles
    sorted_base_titles = sorted(base_job_titles, key=len, reverse=True)
    for base_title in sorted_base_titles:
        if base_title in normalized_title:
            if "senior" in normalized_title and "senior" not in base_title:
                return "senior "+base_title
            if "junior" in normalized_title and "junior" not in base_title:
                return "junior "+base_title
            if "chief" in normalized_title and "chief" not in base_title:
                return "chief "+base_title
            return base_title
    
    return "unmatched"  # Return "unmatched" or some default value if no match is found

# Define a function to match job titles using fuzzy string matching
def fuzzy_match_title(scraped_title, base_job_titles, threshold=90):
    # Use the process function to find the closest match above a certain score threshold
    best_match, score = process.extractOne(normalize_title(scraped_title), base_job_titles)
    # Only accept the match if the score is above the threshold
    return best_match if score >= threshold else "unmatched"

'''
# Match each scraped title to a base title
matched_titles = {title: match_title_to_base(title, base_job_titles) for title in scraped_titles}
matched_titles_fuzzy = {}
for title in [normalize_title(each) for each in scraped_titles]:
    matched_titles_fuzzy[title] = fuzzy_match_title(title, base_job_titles)

def fill_best_value(matched_titles_fuzzy,matched_titles):
    for k,v in matched_titles_fuzzy:
        if v==None:
            matched_titles_fuzzy[k]= matched_titles[k]

    for k,v in matched_titles_fuzzy:
        if v==None:
            matched_titles_fuzzy[k]= matched_titles[k]
'''


df_j_cleaned["title_cleaned"] = df_j_cleaned["title"].apply(lambda x: fuzzy_match_title(x,base_job_titles))
df_j_cleaned["title_cleaned"] = df_j_cleaned["title_cleaned"].apply(lambda x: match_title_to_base(x,base_job_titles))
df_j_cleaned["title_cleaned"] = df_j_cleaned.apply(
    lambda x: x["title_cleaned"] if x["title_cleaned"] != "unmatched" else fuzzy_match_title(x["normTitle"], base_job_titles),
    axis=1
)
df_j_cleaned["title_cleaned"] = df_j_cleaned.apply(
    lambda x: x["title_cleaned"] if x["title_cleaned"] != "unmatched" else match_title_to_base(x["normTitle"], base_job_titles),
    axis=1
)
#df_j_cleaned["displayTitle"] = df_j_cleaned["displayTitle"].apply(lambda x: fuzzy_match_title(x,base_job_titles))
#df_j_cleaned["displayTitle"] = df_j_cleaned["displayTitle"].apply(lambda x: match_title_to_base(x,base_job_titles))

#df_j_cleaned["title"] = df_j_cleaned["title"].apply(lambda x: match_title_to_base(x,base_job_titles))

columns_most_important = ['company', 'truncatedCompany',
 'companyRating',
 'companyReviewCount',
  'searched_title',
    'title',
 'title_cleaned',
 'normTitle',
 'min',
 'max',
 'type',
 'snippet',
 'jobDescription',
 'skills_tagged']

df_j_cleaned = df_j_cleaned[columns_most_important]

#df_j_cleaned.to_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_cleaned_v2.csv")

# %%
df_j_cleaned =  pd.read_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_cleaned_v2.csv")

# %%
#pd.set_option('display.max_rows', 500)


condition =df_j_cleaned["title_cleaned"]=="unmatched"
df_j_cleaned.loc[condition,"title_cleaned"]=df_j_cleaned.loc[condition,"searched_title"]
df_j_cleaned["title_cleaned"] = df_j_cleaned["title_cleaned"].apply(lambda x:x.lower()) 

df_j_cleaned["title_cleaned"] = df_j_cleaned.apply(
    lambda x: x["title_cleaned"] if x["title_cleaned"] != "unmatched" else fuzzy_match_title(x["searched_title"], base_job_titles),
    axis=1
)

df_j_cleaned["title_cleaned"]=df_j_cleaned["title_cleaned"].apply(lambda x:x.replace("(cto)","").strip())
df_j_cleaned["title_cleaned"]=df_j_cleaned["title_cleaned"].apply(lambda x:x.replace("(cio)","").strip())
df_j_cleaned["title_cleaned"].unique()
# Out:
# array(['chief intelligence officer', 'chief information officer',
#        'chief strategy officer', 'chief technology officer',
#        'chief product officer', 'senior data architect', 'data architect',
#        'senior ai developer', 'enterprise architect',
#        'big data architect', 'data engineer', 'senior big data engineer',
#        'database administrator', 'ai architect',
#        'senior machine learning engineer', 'machine learning engineer',
#        'data scientist', 'ai project manager',
#        'senior research scientist', 'research scientist',
#        'principal data scientist', 'research analyst',
#        'quantitative research manager', 'principal scientist',
#        'business intelligence analyst', 'business intelligence manager',
#        'business analyst', 'senior of business intelligence',
#        'business analysis manager',
#        'senior business intelligence analyst',
#        'senior data product manager', 'product analyst', 'data analyst',
#        'director of product management', 'data product manager',
#        'senior data analyst', 'data engineering manager', 'mid-level dba',
#        'senior database administrator', 'senior data engineer',
#        'chief data scientist', 'senior data scientist', 'data manager',
#        'senior of product', 'director of analytics',
#        'vice president of product', 'quantitative analyst',
#        'big data engineer', 'junior data scientist',
#        'director of data science', 'senior business analyst',
#        'machine learning architect', 'data pipeline architect',
#        'senior dba', 'research assistant', 'chief ai officer',
#        'chief data officer', 'machine learning manager',
#        'head of big data', 'director of data engineering',
#        'director of business intelligence', 'head of ai',
#        'head of machine learning', 'ai developer', 'database manager',
#        'data science manager', 'vice president of business intelligence',
#        'chief science officer', 'director of database management',
#        'lead data scientist', 'senior quantitative analyst',
#        'statistician', 'senior statistician', 'director of research',
#        'junior statistician', 'vice president of data science',
#        'senior of data science', 'junior business analyst',
#        'director of quantitative research', 'junior data engineer',
#        'director of business analysis', 'junior ai developer',
#        'lead data engineer', 'junior data analyst', 'junior dba'],
#       dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
def fill_na_type(min_sal,max_sal,type):
    if pd.isna(type):
        if min_sal//1000 or max_sal//1000:
            return "yearly"
        else:
            return "hourly"
    else:
        return type
df_j_cleaned["type"]=df_j_cleaned.apply(lambda x: fill_na_type(x["min"],x["max"],x["type"]),axis=1)


def adjust_max_salary(min_sal,type):
    if type=="yearly":
        return min_sal+10000
    else:
        return min_sal+10
    
df_j_cleaned["max"]=df_j_cleaned[["min","type"]].apply(lambda x :adjust_max_salary(x["min"],x["type"]),axis=1)

for each in df_j_cleaned["title_cleaned"].unique():
    condition = df_j_cleaned["title_cleaned"]==each
    # Condition for filtering ColumnB

    # Calculate the average of ColumnB based on the condition
    average_value_min = df_j_cleaned.loc[condition, 'min'].mean()
    average_value_max = df_j_cleaned.loc[condition, 'max'].mean()

    # Fill missing values in ColumnA with this average
    df_j_cleaned.loc[condition,"min"] = df_j_cleaned.loc[condition,"min"].fillna(average_value_min)
    df_j_cleaned.loc[condition,"max"] = df_j_cleaned.loc[condition,"max"].fillna(average_value_max)

# Assuming a standard work year of 40 hours/week and 52 weeks/year
HOURS_PER_WEEK = 40
WEEKS_PER_YEAR = 52
condition = df_j_cleaned["type"]=="hourly"
df_j_cleaned.loc[condition,"min"]=df_j_cleaned.loc[condition,"min"]*HOURS_PER_WEEK * WEEKS_PER_YEAR
df_j_cleaned.loc[condition,"max"]=df_j_cleaned.loc[condition,"max"]*HOURS_PER_WEEK * WEEKS_PER_YEAR
df_j_cleaned.loc[condition,"type"]="yearly"
df_j_cleaned["min"].fillna(df_j_cleaned["min"].mean(),inplace=True)
df_j_cleaned["max"].fillna(df_j_cleaned["max"].mean(),inplace=True)



# Assuming df is your DataFrame and 'current_salary' is the salary column
scaler = StandardScaler()
df_j_cleaned['normalized_min'] = scaler.fit_transform(df_j_cleaned[['min']])
df_j_cleaned['normalized_max'] = scaler.fit_transform(df_j_cleaned[['max']])

# %%
#df_j_cleaned.to_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_cleaned_all_titles_salary.csv")
#df_j_cleaned.to_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_cleaned_salary.csv")

# %%
## clean course data 


df_c_cleaned = df_c
df_c_cleaned.columns.tolist()



def salary_to_dict(row):
    if pd.isna(row):
        # Return a dictionary with NaN values if the row is NaN
        return {'max': np.nan, 'min': np.nan, 'type': np.nan}
    elif isinstance(row, dict):
        # Return the row as is if it's already a dictionary
        return row
    else:
        # If the row is a string representation of a dictionary (assumed if not NaN or dict),
        # safely evaluate it to a dictionary here
        # Note: Be cautious with `eval`. Here it's mentioned for potential string to dict conversion.
        # In a secure context, confirm the string format and consider `ast.literal_eval` instead.
        try:
            # Convert string to dictionary safely
            dict_row = eval(row)
            return dict_row if isinstance(dict_row, dict) else {'max': np.nan, 'min': np.nan, 'type': np.nan}
        except:
            # In case of error during eval, return NaN values
            return {'max': np.nan, 'min': np.nan, 'type': np.nan}

def  course_price_detail(x):
    if pd.isna(x):
        return np.nan
    else:
        cou_dict = ast.literal_eval(x)
        return cou_dict["amount"]

def  category_primary(x):
    cou_dict = ast.literal_eval(x)
    return cou_dict["url"]

def  labels_return_title(x):
    cou_dict = ast.literal_eval(x)
    if len(cou_dict)==0:
        return "UnDefined"
    return cou_dict[0]["title"]



def  labels_return_url(x):
    cou_dict = ast.literal_eval(x)
    if len(cou_dict)==0:
        return "UnDefined"
    return cou_dict[0]["url"]


def  labels_return_display_name(x):
    cou_dict = ast.literal_eval(x)
    if len(cou_dict)==0:
        return "UnDefined"
    return cou_dict[0]["display_name"]


## Lemmitization and cleaning columns

df_c_cleaned["price"] = df_c_cleaned["price_detail"].apply(lambda x: course_price_detail(x))
df_c_cleaned["requirements_data"] = df_c_cleaned["requirements_data"].apply(lambda x:ast.literal_eval(x)[0])
df_c_cleaned["course_title"]=df_c_cleaned["labels"].apply(lambda x:labels_return_title(x))
df_c_cleaned["course_url"] =df_c_cleaned["labels"].apply(lambda x:labels_return_url(x))
df_c_cleaned["course_display_name"] =df_c_cleaned["labels"].apply(lambda x:labels_return_display_name(x))
df_c_cleaned["objectives"] =df_c_cleaned["objectives"].apply(lambda x:ast.literal_eval(x)[0])
del df_c_cleaned["labels"]
df_c_cleaned["what_you_will_learn_data"] = df_c_cleaned["what_you_will_learn_data"].apply(lambda x:ast.literal_eval(x)[0])
df_c_cleaned["target_audiences"] = df_c_cleaned["target_audiences"].apply(lambda x:ast.literal_eval(x)[0])
del df_c_cleaned["price_detail"]

## merge all description into one    

#clean course data 
def clean_course_df(df):
    df = df.reset_index(drop=True)
    # Create an empty DataFrame with a column named 'single_space' that has one row with a space
    df_space = pd.DataFrame({"single_space": [" "] * len(df)})
    
    df["full_description"] = df["title"]+df_space["single_space"]+df["description"]+df_space["single_space"]+df["headline"]+df_space["single_space"]+df["what_you_will_learn_data"]+df_space["single_space"]+df["objectives"]
    df = clean_lem_stop(df,"full_description")
    course_description = df["full_description"].tolist()
    return df,course_description

clean_course_columns =["title",
"description",
"headline",
"requirements_data",
"what_you_will_learn_data",
"target_audiences",
"objectives",
#"full_description",
"course_title",
"course_display_name"]
for clean_column in clean_course_columns:
    df_c_cleaned[clean_column]=df_c_cleaned[clean_column].astype(str)
    df_c_cleaned = clean_lem_stop(df_c_cleaned,clean_column)

df_c_cleaned,course_descriptions = clean_course_df(df_c_cleaned)



df_c_cleaned_2 = df_c_cleaned.copy()
df_c_cleaned_2["skills_tagged"] = df_c_cleaned_2["full_description"].apply(lambda x:phrase_matcher_model(x,skills_list))

# %%
course_columns_imp = [
 'title',
 'url',
 'description',
 'headline',
 'num_subscribers',
 'rating',
 'num_reviews',
 'num_quizzes',
 'num_lectures',
 'num_curriculum_items',
 'requirements_data',
 'what_you_will_learn_data',
 'target_audiences',
 'estimated_content_length',
 'content_info',
 'instructional_level',
 'objectives',
 'full_description',
 'skills_tagged']

df_c_cleaned_2 = df_c_cleaned_2[course_columns_imp]

# %%
## save processed datasets 

df_c_cl_backup =  df_c_cleaned_2.copy()
#df_j_cleaned.to_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_cleaned.csv")
#df_c_cleaned_2.to_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/course_cleaned.csv")


#df_c_cleaned = pd.read_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/course_cleaned.csv")
#df_j_cleaned=pd.read_csv("/Users/nyzy/Library/CloudStorage/GoogleDrive-nitinmali999@gmail.com/.shortcut-targets-by-id/1yEbTjc1DwwTDd2CB86Il6F-3DhFUn8pU/Data Mining/data/processed_datasets/job_cleaned.csv")

#import ast
#df_j_cleaned["skills_tagged"]=df_j_cleaned["skills_tagged"].apply(lambda x:ast.literal_eval(x))

# %%
df_c_cleaned_2
# Out:
#                                                 title  \
# 0        machine learning z ai python r chatgpt bonus
# 1       python data science machine learning bootcamp
# 2   data science course complete data science boot...
# 3       r programming z r data science real exercises
# 4    deep learning z neural networks ai chatgpt bonus
# 5           statistics data science business analysis
# 6        data science z hands exercises chatgpt bonus
# 7     artificial intelligence z build ai incl chatgpt
# 8   machine learning data science generative ai py...
# 9         python z python data science real exercises
# 10                      spark python big data pyspark
# 11                        data analysis pandas python
# 12    complete machine learning data science bootcamp
# 13                  apache spark scala hands big data
# 14     complete guide tensorflow deep learning python
# 15           data science machine learning bootcamp r
# 16          taming big data apache spark python hands
# 17             nlp natural language processing python
# 18         introduction machine learning data science
# 19   python machine learning data science masterclass
# 20  data science natural language processing nlp p...
# 21       statistics business analytics data science z
# 22   tensorflow deep learning artificial intelligence
# 23  artificial intelligence reinforcement learning...
# 24           dp azure data fundamentals exam prep day
# 25  data science deep learning neural networks python
# 26      tensorflow developer certificate zero mastery
# 27    r programming advanced analytics r data science
# 28          interactive python dashboards plotly dash
# 29   natural language processing deep learning python
# 30   complete tensorflow keras deep learning bootcamp
# 31    apache spark spark programming python beginners
# 32            complete machine learning course python
# 33         bayesian machine learning python b testing
# 34          machine learning absolute beginners level
# 35  deep learning computer vision z ai chatgpt bon...
# 36       probability statistics business data science
# 37  deep learning advanced natural language proces...
# 38  deep learning prerequisites linear regression ...
# 39  intro data science quickstart guide ai chatgpt...
# 40    deep learning advanced computer vision gans ssd
# 41    complete data science machine learning bootcamp
# 42                     statistics data analysis excel
# 43  deep learning convolutional neural networks py...
# 44            machine learning deep learning python r
# 45              scala spark big data machine learning
# 46  artificial intelligence machine learning business
# 47          mathematical foundations machine learning
# 48     advanced ai deep reinforcement learning python
# 49  sql database design z learn ms sql server post...
# 50                 deployment machine learning models
# 51  cluster analysis unsupervised machine learning...
# 52              r programming statistics data science
# 53     deep learning recurrent neural networks python
# 54                             data integration guide
# 55              pytorch deep learning python bootcamp
# 56  deep learning prerequisites logistic regressio...
# 57         python machine learning financial analysis
# 58  complete self driving car course applied deep ...
# 59     artificial intelligence business chatgpt bonus
# 60       machine learning z ai python r chatgpt bonus
# 61      python data science machine learning bootcamp
# 62  data science course complete data science boot...
# 63      r programming z r data science real exercises
# 64   deep learning z neural networks ai chatgpt bonus
# 65          statistics data science business analysis
# 66       data science z hands exercises chatgpt bonus
# 67    artificial intelligence z build ai incl chatgpt
# 68  machine learning data science generative ai py...
# 69        python z python data science real exercises
# 70                      spark python big data pyspark
# 71                        data analysis pandas python
# 72    complete machine learning data science bootcamp
# 73                  apache spark scala hands big data
# 74     complete guide tensorflow deep learning python
# 75           data science machine learning bootcamp r
# 76          taming big data apache spark python hands
# 77             nlp natural language processing python
# 78         introduction machine learning data science
# 79   python machine learning data science masterclass
# 80  data science natural language processing nlp p...
# 81       statistics business analytics data science z
# 82   tensorflow deep learning artificial intelligence
# 83  artificial intelligence reinforcement learning...
# 84           dp azure data fundamentals exam prep day
# 85  data science deep learning neural networks python
# 86      tensorflow developer certificate zero mastery
# 87    r programming advanced analytics r data science
# 88          interactive python dashboards plotly dash
# 89   natural language processing deep learning python
# 90   complete tensorflow keras deep learning bootcamp
# 91    apache spark spark programming python beginners
# 92            complete machine learning course python
# 93         bayesian machine learning python b testing
# 94          machine learning absolute beginners level
# 95  deep learning computer vision z ai chatgpt bon...
# 96       probability statistics business data science
# 97  deep learning advanced natural language proces...
# 98  deep learning prerequisites linear regression ...
# 99  intro data science quickstart guide ai chatgpt...
#
#                                                   url  \
# 0       https://www.udemy.com/course/machinelearning/
# 1   https://www.udemy.com/course/python-for-data-s...
# 2   https://www.udemy.com/course/the-data-science-...
# 3         https://www.udemy.com/course/r-programming/
# 4          https://www.udemy.com/course/deeplearning/
# 5   https://www.udemy.com/course/statistics-for-da...
# 6           https://www.udemy.com/course/datascience/
# 7   https://www.udemy.com/course/artificial-intell...
# 8   https://www.udemy.com/course/data-science-and-...
# 9         https://www.udemy.com/course/python-coding/
# 10  https://www.udemy.com/course/spark-and-python-...
# 11  https://www.udemy.com/course/data-analysis-wit...
# 12  https://www.udemy.com/course/complete-machine-...
# 13  https://www.udemy.com/course/apache-spark-with...
# 14  https://www.udemy.com/course/complete-guide-to...
# 15  https://www.udemy.com/course/data-science-and-...
# 16  https://www.udemy.com/course/taming-big-data-w...
# 17  https://www.udemy.com/course/nlp-natural-langu...
# 18  https://www.udemy.com/course/machine-learning-...
# 19  https://www.udemy.com/course/python-for-machin...
# 20  https://www.udemy.com/course/data-science-natu...
# 21      https://www.udemy.com/course/data-statistics/
# 22  https://www.udemy.com/course/deep-learning-ten...
# 23  https://www.udemy.com/course/artificial-intell...
# 24          https://www.udemy.com/course/dp900-azure/
# 25  https://www.udemy.com/course/data-science-deep...
# 26  https://www.udemy.com/course/tensorflow-develo...
# 27          https://www.udemy.com/course/r-analytics/
# 28  https://www.udemy.com/course/interactive-pytho...
# 29  https://www.udemy.com/course/natural-language-...
# 30  https://www.udemy.com/course/complete-tensorfl...
# 31  https://www.udemy.com/course/apache-spark-prog...
# 32  https://www.udemy.com/course/machine-learning-...
# 33  https://www.udemy.com/course/bayesian-machine-...
# 34  https://www.udemy.com/course/machine-learning-...
# 35  https://www.udemy.com/course/computer-vision-a-z/
# 36  https://www.udemy.com/course/probability-and-s...
# 37  https://www.udemy.com/course/deep-learning-adv...
# 38  https://www.udemy.com/course/data-science-line...
# 39  https://www.udemy.com/course/intro-to-data-sci...
# 40  https://www.udemy.com/course/advanced-computer...
# 41  https://www.udemy.com/course/python-data-scien...
# 42  https://www.udemy.com/course/statistics-using-...
# 43  https://www.udemy.com/course/deep-learning-con...
# 44  https://www.udemy.com/course/data_science_a_to_z/
# 45  https://www.udemy.com/course/scala-and-spark-f...
# 46  https://www.udemy.com/course/artificial-intell...
# 47  https://www.udemy.com/course/machine-learning-...
# 48  https://www.udemy.com/course/deep-reinforcemen...
# 49         https://www.udemy.com/course/sqldatabases/
# 50  https://www.udemy.com/course/deployment-of-mac...
# 51  https://www.udemy.com/course/cluster-analysis-...
# 52  https://www.udemy.com/course/r-programming-for...
# 53  https://www.udemy.com/course/deep-learning-rec...
# 54  https://www.udemy.com/course/data-integration-...
# 55  https://www.udemy.com/course/pytorch-for-deep-...
# 56  https://www.udemy.com/course/data-science-logi...
# 57  https://www.udemy.com/course/ml-and-python-in-...
# 58  https://www.udemy.com/course/applied-deep-lear...
# 59      https://www.udemy.com/course/ai-for-business/
# 60      https://www.udemy.com/course/machinelearning/
# 61  https://www.udemy.com/course/python-for-data-s...
# 62  https://www.udemy.com/course/the-data-science-...
# 63        https://www.udemy.com/course/r-programming/
# 64         https://www.udemy.com/course/deeplearning/
# 65  https://www.udemy.com/course/statistics-for-da...
# 66          https://www.udemy.com/course/datascience/
# 67  https://www.udemy.com/course/artificial-intell...
# 68  https://www.udemy.com/course/data-science-and-...
# 69        https://www.udemy.com/course/python-coding/
# 70  https://www.udemy.com/course/spark-and-python-...
# 71  https://www.udemy.com/course/data-analysis-wit...
# 72  https://www.udemy.com/course/complete-machine-...
# 73  https://www.udemy.com/course/apache-spark-with...
# 74  https://www.udemy.com/course/complete-guide-to...
# 75  https://www.udemy.com/course/data-science-and-...
# 76  https://www.udemy.com/course/taming-big-data-w...
# 77  https://www.udemy.com/course/nlp-natural-langu...
# 78  https://www.udemy.com/course/machine-learning-...
# 79  https://www.udemy.com/course/python-for-machin...
# 80  https://www.udemy.com/course/data-science-natu...
# 81      https://www.udemy.com/course/data-statistics/
# 82  https://www.udemy.com/course/deep-learning-ten...
# 83  https://www.udemy.com/course/artificial-intell...
# 84          https://www.udemy.com/course/dp900-azure/
# 85  https://www.udemy.com/course/data-science-deep...
# 86  https://www.udemy.com/course/tensorflow-develo...
# 87          https://www.udemy.com/course/r-analytics/
# 88  https://www.udemy.com/course/interactive-pytho...
# 89  https://www.udemy.com/course/natural-language-...
# 90  https://www.udemy.com/course/complete-tensorfl...
# 91  https://www.udemy.com/course/apache-spark-prog...
# 92  https://www.udemy.com/course/machine-learning-...
# 93  https://www.udemy.com/course/bayesian-machine-...
# 94  https://www.udemy.com/course/machine-learning-...
# 95  https://www.udemy.com/course/computer-vision-a-z/
# 96  https://www.udemy.com/course/probability-and-s...
# 97  https://www.udemy.com/course/deep-learning-adv...
# 98  https://www.udemy.com/course/data-science-line...
# 99  https://www.udemy.com/course/intro-to-data-sci...
#
#                                           description  \
# 0   p interested field machine learning nbsp cours...
# 1   p ready start path data scientist p p comprehe...
# 2   p strong problem strong p p data scientist bes...
# 3   p learn r programming p p lots r courses lectu...
# 4   p seen kickstarter p p artificial intelligence...
# 5   p strong want work marketing analyst business ...
# 6   p extremely hands incredibly practical unbelie...
# 7   p strong nbsp nbsp seen nbsp nbsp kickstarter ...
# 8   p strong new nbsp em updated em strong em em e...
# 9   p learn python programming p p lots python nbs...
# 10  p strong learn latest big data technology spar...
# 11  p strong student testimonials strong p ul li p...
# 12  p strong selling machine learning data science...
# 13  p strong new completely updated recorded spark...
# 14  p strong welcome complete guide tensorflow dee...
# 15  p data scientist ranked number job glassdoor a...
# 16  p strong new nbsp strong em updated nbsp spark...
# 17  p welcome best natural language processing cou...
# 18  p strong course recently updated nov strong p ...
# 19  p strong em complete course online learning py...
# 20  p course build multiple practical systems natu...
# 21  p aiming career data scientist business analys...
# 22  p welcome tensorflow p p br p p exciting time ...
# 23  p people talk strong artificial intelligence s...
# 24  p strong learn nbsp azure nbsp database nbsp d...
# 25  p course started building strong artificial ne...
# 26  p strong launched modern best practices buildi...
# 27  p ready r programming skills level p p want tr...
# 28  p strong welcome python visualization dashboar...
# 29  p course going look strong nlp natural languag...
# 30  p course guide use google latest tensorflow fr...
# 31  p strong em course require prior knowledge apa...
# 32  p em complete machine learning course python e...
# 33  p course strong b testing strong p p b testing...
# 34  p strong feedback students strong p p em excel...
# 35  p definitely heard ai deep learning ask positi...
# 36  p welcome probability statistics business data...
# 37  p hard believe year released course strong dee...
# 38  p course teaches popular technique strong mach...
# 39  p demand data scientists immense course learn ...
# 40  p strong latest update strong instead ssd use ...
# 41  p welcome complete data science machine learni...
# 42  p strong em gt gt gt start loving data making ...
# 43  p nbsp nbsp nbsp tensorflow python nbsp p p le...
# 44  p looking complete strong machine learning dee...
# 45  p learn utilize valuable tech skills market to...
# 46  p prepared inevitable ai revolution leverage c...
# 47  p mathematics forms core data science machine ...
# 48  p course application strong deep learning stro...
# 49  p interested career data science data analytic...
# 50  p welcome deployment machine learning models s...
# 51  p strong cluster analysis strong staple strong...
# 52  p strong em r programming statistics data scie...
# 53  p nbsp nbsp nbsp tensorflow python nbsp p p le...
# 54  p according world economic forum beginning num...
# 55  p welcome best online course learning deep lea...
# 56  p course lead strong deep learning strong stro...
# 57  p ready learn python programming fundamentals ...
# 58  p self driving cars rapidly strong transformat...
# 59  p strong structure course strong br p p optimi...
# 60  p interested field machine learning nbsp cours...
# 61  p ready start path data scientist p p comprehe...
# 62  p strong problem strong p p data scientist bes...
# 63  p learn r programming p p lots r courses lectu...
# 64  p seen kickstarter p p artificial intelligence...
# 65  p strong want work marketing analyst business ...
# 66  p extremely hands incredibly practical unbelie...
# 67  p strong nbsp nbsp seen nbsp nbsp kickstarter ...
# 68  p strong new nbsp em updated em strong em em e...
# 69  p learn python programming p p lots python nbs...
# 70  p strong learn latest big data technology spar...
# 71  p strong student testimonials strong p ul li p...
# 72  p strong selling machine learning data science...
# 73  p strong new completely updated recorded spark...
# 74  p strong welcome complete guide tensorflow dee...
# 75  p data scientist ranked number job glassdoor a...
# 76  p strong new nbsp strong em updated nbsp spark...
# 77  p welcome best natural language processing cou...
# 78  p strong course recently updated nov strong p ...
# 79  p strong em complete course online learning py...
# 80  p course build multiple practical systems natu...
# 81  p aiming career data scientist business analys...
# 82  p welcome tensorflow p p br p p exciting time ...
# 83  p people talk strong artificial intelligence s...
# 84  p strong learn nbsp azure nbsp database nbsp d...
# 85  p course started building strong artificial ne...
# 86  p strong launched modern best practices buildi...
# 87  p ready r programming skills level p p want tr...
# 88  p strong welcome python visualization dashboar...
# 89  p course going look strong nlp natural languag...
# 90  p course guide use google latest tensorflow fr...
# 91  p strong em course require prior knowledge apa...
# 92  p em complete machine learning course python e...
# 93  p course strong b testing strong p p b testing...
# 94  p strong feedback students strong p p em excel...
# 95  p definitely heard ai deep learning ask positi...
# 96  p welcome probability statistics business data...
# 97  p hard believe year released course strong dee...
# 98  p course teaches popular technique strong mach...
# 99  p demand data scientists immense course learn ...
#
#                                              headline  num_subscribers  \
# 0   learn create machine learning algorithms pytho...           993456
# 1   learn use numpy pandas seaborn matplotlib plot...           674125
# 2   complete data science training mathematics sta...           634583
# 3   learn programming r r studio data analytics da...           261248
# 4   learn create deep learning algorithms python m...           366900
# 5   statistics need office descriptive inferential...           186978
# 6   learn data science step step real analytics ex...           215475
# 7   combine power data science machine learning de...           239954
# 8   complete hands machine learning ai tutorial da...           182709
# 9   programming python data analytics data science...           158319
# 10  learn use spark python including spark streami...           125837
# 11  analyze data quickly easily python powerful pa...           189485
# 12  learn data science data analysis machine learn...           106712
# 13  apache spark tutorial hands examples analyzing...            94162
# 14  learn use google deep learning framework tenso...            95188
# 15  learn use r programming language data science ...            91558
# 16  pyspark tutorial hands examples analyzing larg...            94031
# 17  learn use machine learning spacy nltk scikit l...            79660
# 18  primer machine learning data science revealed ...            62512
# 19  learn data science machine learning python inc...            96858
# 20  applications decrypting ciphers spam detection...            46107
# 21  learn core stats data science career master st...            62818
# 22  machine learning neural networks computer visi...            48537
# 23  complete guide reinforcement learning stock tr...            44894
# 24  learn basics azure database services certified...            48947
# 25  depth look neural network theory machine learn...            54848
# 26  pass tensorflow developer certification exam g...            61420
# 27  r r studio skills level data analytics data sc...            60197
# 28  learn create interactive plots intelligent das...            46681
# 29  complete guide deriving implementing word vec ...            45658
# 30  learn use python deep learning google latest t...            47735
# 31              data engineering spark structured api            39360
# 32  build portfolio machine learning projects pyth...            38006
# 33  data science machine learning data analytics t...            36882
# 34  learn fundamental concepts artificial intellig...            45449
# 35  wizard latest computer vision tools exist dete...            47716
# 36  learn apply probability statistics real data s...            33842
# 37  natural language processing nlp sequence seque...            32639
# 38  data science machine learning artificial intel...            33210
# 39  learn critical elements data science visualiza...            23341
# 40  vgg resnet inception ssd retinanet neural styl...            36728
# 41  learn python tensorflow deep learning regressi...            45732
# 42  plain simple lessons descriptive inferential s...            23007
# 43  tensorflow cnns computer vision natural langua...            37527
# 44  covers regression decision trees svm neural ne...           363960
# 45  learn latest big data technology spark scala i...            31269
# 46  ultimate artificial intelligence machine learn...            18076
# 47  essential linear algebra calculus hands numpy ...           112877
# 48  complete guide mastering artificial intelligen...            38447
# 49  learn sql server postgresql enhance data analy...            29896
# 50  learn integrate robust reliable machine learni...            33224
# 51  data science techniques pattern recognition da...            26448
# 52  r programming data science data analysis apply...            27367
# 53  gru lstm time series forecasting stock predict...            35573
# 54  learn data integrated following principles bus...            11146
# 55  learn create state art neural networks deep le...            28543
# 56  data science machine learning artificial intel...            30420
# 57  master python programming fundamentals harness...            98557
# 58  learn use deep learning computer vision machin...            23380
# 59  solve real world business problems ai solution...            28726
# 60  learn create machine learning algorithms pytho...           993456
# 61  learn use numpy pandas seaborn matplotlib plot...           674125
# 62  complete data science training mathematics sta...           634583
# 63  learn programming r r studio data analytics da...           261248
# 64  learn create deep learning algorithms python m...           366900
# 65  statistics need office descriptive inferential...           186978
# 66  learn data science step step real analytics ex...           215475
# 67  combine power data science machine learning de...           239954
# 68  complete hands machine learning ai tutorial da...           182709
# 69  programming python data analytics data science...           158319
# 70  learn use spark python including spark streami...           125837
# 71  analyze data quickly easily python powerful pa...           189485
# 72  learn data science data analysis machine learn...           106712
# 73  apache spark tutorial hands examples analyzing...            94162
# 74  learn use google deep learning framework tenso...            95188
# 75  learn use r programming language data science ...            91558
# 76  pyspark tutorial hands examples analyzing larg...            94031
# 77  learn use machine learning spacy nltk scikit l...            79660
# 78  primer machine learning data science revealed ...            62512
# 79  learn data science machine learning python inc...            96858
# 80  applications decrypting ciphers spam detection...            46107
# 81  learn core stats data science career master st...            62818
# 82  machine learning neural networks computer visi...            48537
# 83  complete guide reinforcement learning stock tr...            44894
# 84  learn basics azure database services certified...            48947
# 85  depth look neural network theory machine learn...            54848
# 86  pass tensorflow developer certification exam g...            61420
# 87  r r studio skills level data analytics data sc...            60197
# 88  learn create interactive plots intelligent das...            46681
# 89  complete guide deriving implementing word vec ...            45658
# 90  learn use python deep learning google latest t...            47735
# 91              data engineering spark structured api            39360
# 92  build portfolio machine learning projects pyth...            38006
# 93  data science machine learning data analytics t...            36882
# 94  learn fundamental concepts artificial intellig...            45449
# 95  wizard latest computer vision tools exist dete...            47716
# 96  learn apply probability statistics real data s...            33842
# 97  natural language processing nlp sequence seque...            32639
# 98  data science machine learning artificial intel...            33210
# 99  learn critical elements data science visualiza...            23341
#
#       rating  num_reviews  num_quizzes  num_lectures  num_curriculum_items  \
# 0   4.513425       176950           39           468                   507
# 1   4.588927       136746            1           184                   185
# 2   4.594564       131509          281           518                   799
# 3   4.662838        51993            5            89                    94
# 4   4.501419        44403            0           230                   230
# 5   4.549923        40278           42            92                   134
# 6   4.585904        33599            1           233                   234
# 7   4.381688        32664            1           124                   125
# 8   4.619988        29764            0           147                   147
# 9   4.558244        27113            6            84                    90
# 10  4.523367        22873            0            67                    67
# 11  4.619723        20765           39           249                   288
# 12  4.633599        18888            2           382                   384
# 13  4.632853        17262            6            73                    79
# 14  4.561438        16773            0           108                   108
# 15  4.676823        16430            1           128                   129
# 16  4.554968        15268            0            68                    68
# 17  4.585359        15115            1            80                    81
# 18  4.555354        13772            3            64                    67
# 19  4.646133        13510            4           232                   236
# 20  4.603750        11997            0            94                    94
# 21  4.525220        11233            5            56                    61
# 22  4.641578        10350            0           165                   165
# 23  4.796079         9824            0           140                   140
# 24  4.521355         9774            2            49                    51
# 25  4.660120         9444            4            94                    98
# 26  4.653305         8865            2           424                   426
# 27  4.643925         8644            3            60                    63
# 28  4.417147         8536            0            71                    71
# 29  4.637453         7858            0           110                   110
# 30  4.631566         7782            1           116                   117
# 31  4.542278         7223            9            94                   103
# 32  4.458542         6926            3           203                   206
# 33  4.587808         6696            0           114                   114
# 34  4.508656         6568            5            25                    30
# 35  4.196091         6515            6            95                   101
# 36  4.670479         6475           17            53                    70
# 37  4.625027         6292            0            67                    67
# 38  4.644806         6181            4            57                    61
# 39  4.544537         5923            0            48                    48
# 40  4.729925         5620            0           140                   140
# 41  4.658142         5619            7           207                   214
# 42  4.618312         5419           13           114                   127
# 43  4.714412         5406            0           117                   117
# 44  4.424424         5386            6           301                   307
# 45  4.620375         5281            0            80                    80
# 46  4.481357         5431           19            48                    67
# 47  4.520567         5187            1           115                   116
# 48  4.546164         5183            0            88                    88
# 49  4.346792         5142            3           114                   117
# 50  4.372408         4992            1           219                   224
# 51  4.627205         4909            0            60                    60
# 52  4.554353         4787           16           128                   144
# 53  4.607714         4782            0           122                   122
# 54  4.538903         4495            9            40                    49
# 55  4.507283         4325            1            97                    98
# 56  4.542166         4297            5            63                    68
# 57  4.386377         4252            0           138                   138
# 58  4.680695         3904            0           170                   170
# 59  4.447960         3866            0           121                   121
# 60  4.513425       176950           39           468                   507
# 61  4.588927       136746            1           184                   185
# 62  4.594564       131509          281           518                   799
# 63  4.662838        51993            5            89                    94
# 64  4.501419        44403            0           230                   230
# 65  4.549923        40278           42            92                   134
# 66  4.585904        33599            1           233                   234
# 67  4.381688        32664            1           124                   125
# 68  4.619988        29764            0           147                   147
# 69  4.558244        27113            6            84                    90
# 70  4.523367        22873            0            67                    67
# 71  4.619723        20765           39           249                   288
# 72  4.633599        18888            2           382                   384
# 73  4.632853        17262            6            73                    79
# 74  4.561438        16773            0           108                   108
# 75  4.676823        16430            1           128                   129
# 76  4.554968        15268            0            68                    68
# 77  4.585359        15115            1            80                    81
# 78  4.555354        13772            3            64                    67
# 79  4.646133        13510            4           232                   236
# 80  4.603750        11997            0            94                    94
# 81  4.525220        11233            5            56                    61
# 82  4.641578        10350            0           165                   165
# 83  4.796079         9824            0           140                   140
# 84  4.521355         9774            2            49                    51
# 85  4.660120         9444            4            94                    98
# 86  4.653305         8865            2           424                   426
# 87  4.643925         8644            3            60                    63
# 88  4.417147         8536            0            71                    71
# 89  4.637453         7858            0           110                   110
# 90  4.631566         7782            1           116                   117
# 91  4.542278         7223            9            94                   103
# 92  4.458542         6926            3           203                   206
# 93  4.587808         6696            0           114                   114
# 94  4.508656         6568            5            25                    30
# 95  4.196091         6515            6            95                   101
# 96  4.670479         6475           17            53                    70
# 97  4.625027         6292            0            67                    67
# 98  4.644806         6181            4            57                    61
# 99  4.544537         5923            0            48                    48
#
#                                     requirements_data  \
# 0                       high school mathematics level
# 1                              programming experience
# 2              prior experience required start basics
# 3   prior knowledge experience needed passion succ...
# 4                       high school mathematics level
# 5   absolutely experience required start basics gr...
# 6                                     passion success
# 7                                   high school maths
# 8   need desktop computer windows mac linux capabl...
# 9   prior knowledge experience needed passion succ...
# 10  general programming skills language preferrabl...
# 11  basic intermediate experience microsoft excel ...
# 12  prior experience needed math statistics start ...
# 13  prior programming scripting experience require...
# 14            knowledge programming preferably python
# 15                computer access download privileges
# 16  access personal computer course uses windows s...
# 17                          understand general python
# 18                passion learn basic computer skills
# 19           basic python knowledge capable functions
# 20                                install python free
# 21                  basic knowledge high school maths
# 22                             know code python numpy
# 23                               calculus derivatives
# 24                     interest azure cloud computing
# 25  basic math calculus derivatives matrix arithme...
# 26    mac windows linux operating systems work course
# 27                                  basic knowledge r
# 28                             knowledge basic python
# 29  install numpy matplotlib sci kit learn theano ...
# 30                                   know code python
# 31  programming knowledge python programming language
# 32       basic python programming knowledge necessary
# 33  probability joint marginal conditional distrib...
# 34  specific prerequisites starting training desig...
# 35                                  high school maths
# 36                                 paper pencil notes
# 37                           understand deep learning
# 38                                derivative calculus
# 39       passion build successful data science career
# 40  know build train use cnn library preferably py...
# 41      programming experience needed teach need know
# 42                basic understanding microsoft excel
# 43  basic math taking derivatives matrix arithmeti...
# 44  students need install anaconda software separa...
# 45               basic programming knowledge language
# 46  course assume prior knowledge artificial intel...
# 47  code demos python experience object oriented p...
# 48  know reinforcement learning basics mdps dynami...
# 49                          basic knowledge computers
# 50                                python installation
# 51                             know code python numpy
# 52              need install r studio lectures course
# 53  basic math taking derivatives matrix arithmeti...
# 54                             basic knowledge domain
# 55  understanding python basic topics data types l...
# 56          derivatives matrix arithmetic probability
# 57                          prior experience required
# 58                                   working computer
# 59                                  high school maths
# 60                      high school mathematics level
# 61                             programming experience
# 62             prior experience required start basics
# 63  prior knowledge experience needed passion succ...
# 64                      high school mathematics level
# 65  absolutely experience required start basics gr...
# 66                                    passion success
# 67                                  high school maths
# 68  need desktop computer windows mac linux capabl...
# 69  prior knowledge experience needed passion succ...
# 70  general programming skills language preferrabl...
# 71  basic intermediate experience microsoft excel ...
# 72  prior experience needed math statistics start ...
# 73  prior programming scripting experience require...
# 74            knowledge programming preferably python
# 75                computer access download privileges
# 76  access personal computer course uses windows s...
# 77                          understand general python
# 78                passion learn basic computer skills
# 79           basic python knowledge capable functions
# 80                                install python free
# 81                  basic knowledge high school maths
# 82                             know code python numpy
# 83                               calculus derivatives
# 84                     interest azure cloud computing
# 85  basic math calculus derivatives matrix arithme...
# 86    mac windows linux operating systems work course
# 87                                  basic knowledge r
# 88                             knowledge basic python
# 89  install numpy matplotlib sci kit learn theano ...
# 90                                   know code python
# 91  programming knowledge python programming language
# 92       basic python programming knowledge necessary
# 93  probability joint marginal conditional distrib...
# 94  specific prerequisites starting training desig...
# 95                                  high school maths
# 96                                 paper pencil notes
# 97                           understand deep learning
# 98                                derivative calculus
# 99       passion build successful data science career
#
#                              what_you_will_learn_data  \
# 0                    master machine learning python r
# 1            use python data science machine learning
# 2   course provides entire toolbox need data scien...
# 3                          learn program r good level
# 4     understand intuition artificial neural networks
# 5                  understand fundamentals statistics
# 6   successfully perform steps complex data scienc...
# 7                                            build ai
# 8   build artificial neural networks tensorflow keras
# 9                     learn program python good level
# 10                  use python spark analyze big data
# 11  perform multitude data operations python popul...
# 12                               data scientist hired
# 13  develop distributed code scala programming lan...
# 14                    understand neural networks work
# 15                                          program r
# 16          use dataframes structured streaming spark
# 17                       learn work text files python
# 18  genuinely understand computer science algorith...
# 19     learn use data science machine learning python
# 20  write cipher decryption algorithm genetic algo...
# 21                     understand normal distribution
# 22  artificial neural networks anns deep neural ne...
# 23  apply gradient based supervised machine learni...
# 24               pass azure dp data fundamentals exam
# 25  learn deep learning works diagrams magical bla...
# 26  learn pass google official tensorflow develope...
# 27                         perform data preparation r
# 28  learn plotly create plots like bar charts line...
# 29                      understand implement word vec
# 30                 learn use tensorflow deep learning
# 31         apache spark foundation spark architecture
# 32  machine learning engineers earn average ideal ...
# 33  use adaptive algorithms improve b testing perf...
# 34  artificial intelligence machine learning deep ...
# 35            toolbox powerful computer vision models
# 36                      understand basics probability
# 37  build text classification system spam detectio...
# 38  derive solve linear regression model apply app...
# 39                        entire data science process
# 40                 understand apply transfer learning
# 41            learn program python practical projects
# 42  learn descriptive inferential statistics help ...
# 43        understand convolution useful deep learning
# 44  learn solve real life problem machine learning...
# 45                              use scala programming
# 46  applications artificial intelligence machine l...
# 47  understand fundamentals linear algebra calculu...
# 48         build deep learning agents including dqn c
# 49                           create basic sql queries
# 50  build machine learning model apis deploy model...
# 51               understand regular k means algorithm
# 52                   learn fundamentals programming r
# 53  apply rnns time series forecasting tackle ubiq...
# 54  data integration concepts principles main feat...
# 55                 learn use numpy format data arrays
# 56         program logistic regression scratch python
# 57  master python programming fundamentals data sc...
# 58  learn apply computer vision deep learning tech...
# 59                        optimize business processes
# 60                   master machine learning python r
# 61           use python data science machine learning
# 62  course provides entire toolbox need data scien...
# 63                         learn program r good level
# 64    understand intuition artificial neural networks
# 65                 understand fundamentals statistics
# 66  successfully perform steps complex data scienc...
# 67                                           build ai
# 68  build artificial neural networks tensorflow keras
# 69                    learn program python good level
# 70                  use python spark analyze big data
# 71  perform multitude data operations python popul...
# 72                               data scientist hired
# 73  develop distributed code scala programming lan...
# 74                    understand neural networks work
# 75                                          program r
# 76          use dataframes structured streaming spark
# 77                       learn work text files python
# 78  genuinely understand computer science algorith...
# 79     learn use data science machine learning python
# 80  write cipher decryption algorithm genetic algo...
# 81                     understand normal distribution
# 82  artificial neural networks anns deep neural ne...
# 83  apply gradient based supervised machine learni...
# 84               pass azure dp data fundamentals exam
# 85  learn deep learning works diagrams magical bla...
# 86  learn pass google official tensorflow develope...
# 87                         perform data preparation r
# 88  learn plotly create plots like bar charts line...
# 89                      understand implement word vec
# 90                 learn use tensorflow deep learning
# 91         apache spark foundation spark architecture
# 92  machine learning engineers earn average ideal ...
# 93  use adaptive algorithms improve b testing perf...
# 94  artificial intelligence machine learning deep ...
# 95            toolbox powerful computer vision models
# 96                      understand basics probability
# 97  build text classification system spam detectio...
# 98  derive solve linear regression model apply app...
# 99                        entire data science process
#
#                                      target_audiences  \
# 0                         interested machine learning
# 1          course meant people programming experience
# 2         course want data scientist want learn field
# 3                         course want learn program r
# 4                            interested deep learning
# 5                     people want career data science
# 6                       anybody interest data science
# 7   interested artificial intelligence machine lea...
# 8   software developers programmers want transitio...
# 9                    course want learn program python
# 10               knows python like learn use big data
# 11                    data analysts business analysts
# 12  zero experience beginner junior wants learn ma...
# 13  software engineers want expand skills world bi...
# 14  python students eager learn latest deep learni...
# 15                          interested data scientist
# 16  people software development background want le...
# 17  python developers interested learning use natu...
# 18  load python start r need course introductory c...
# 19  beginner python developers curious machine lea...
# 20  students comfortable writing python code loops...
# 21      anybody wants master stats business analytics
# 22  beginners advanced students want learn deep le...
# 23  wants learn artificial intelligence data scien...
# 24                 students starting topic cloud data
# 25  students interested machine learning tidbits n...
# 26  wants pass tensorflow developer exam join goog...
# 27        anybody basic r knowledge like skills level
# 28  python developers interested learning create i...
# 29  students professionals want create word vector...
# 30  python developers interested learning tensorfl...
# 31  software engineers architects willing design d...
# 32  willing interested learn machine learning algo...
# 33  students professionals technical background wa...
# 34                 interested familiar ai ml concepts
# 35  interested computer vision artificial intellig...
# 36  interested learning apply probability statisti...
# 37  students machine learning deep learning artifi...
# 38  people interested data science machine learnin...
# 39                  generally interested data science
# 40  students professionals want knowledge computer...
# 41  want learn code building fun useful projects c...
# 42  business managers data analysts trying decisio...
# 43  students professionals interested deep learnin...
# 44                people pursuing career data science
# 45  knows program interested learning big data tec...
# 46                cxos business managers mba students
# 47  use high level software libraries e g scikit l...
# 48  professionals students strong technical backgr...
# 49                     anybody wants learn postgresql
# 50  data scientists want deploy machine learning m...
# 51  students professionals interested machine lear...
# 52                           aspiring data scientists
# 53  students professionals interested deep learnin...
# 54                                 data professionals
# 55  intermediate advanced python developers wantin...
# 56    adult learners want field data science big data
# 57  financial analysts want harness power data sci...
# 58           interest deep learning self driving cars
# 59  business driven people eager learn leverage ai...
# 60                        interested machine learning
# 61         course meant people programming experience
# 62        course want data scientist want learn field
# 63                        course want learn program r
# 64                           interested deep learning
# 65                    people want career data science
# ...
# 20  write cipher decryption algorithm genetic algo...
# 21                     understand normal distribution
# 22  artificial neural networks anns deep neural ne...
# 23  apply gradient based supervised machine learni...
# 24               pass azure dp data fundamentals exam
# 25  learn deep learning works diagrams magical bla...
# 26  learn pass google official tensorflow develope...
# 27                         perform data preparation r
# 28  learn plotly create plots like bar charts line...
# 29                      understand implement word vec
# 30                 learn use tensorflow deep learning
# 31         apache spark foundation spark architecture
# 32  machine learning engineers earn average ideal ...
# 33  use adaptive algorithms improve b testing perf...
# 34  artificial intelligence machine learning deep ...
# 35            toolbox powerful computer vision models
# 36                      understand basics probability
# 37  build text classification system spam detectio...
# 38  derive solve linear regression model apply app...
# 39                        entire data science process
# 40                 understand apply transfer learning
# 41            learn program python practical projects
# 42  learn descriptive inferential statistics help ...
# 43        understand convolution useful deep learning
# 44  learn solve real life problem machine learning...
# 45                              use scala programming
# 46  applications artificial intelligence machine l...
# 47  understand fundamentals linear algebra calculu...
# 48         build deep learning agents including dqn c
# 49                           create basic sql queries
# 50  build machine learning model apis deploy model...
# 51               understand regular k means algorithm
# 52                   learn fundamentals programming r
# 53  apply rnns time series forecasting tackle ubiq...
# 54  data integration concepts principles main feat...
# 55                 learn use numpy format data arrays
# 56         program logistic regression scratch python
# 57  master python programming fundamentals data sc...
# 58  learn apply computer vision deep learning tech...
# 59                        optimize business processes
# 60                   master machine learning python r
# 61           use python data science machine learning
# 62  course provides entire toolbox need data scien...
# 63                         learn program r good level
# 64    understand intuition artificial neural networks
# 65                 understand fundamentals statistics
# 66  successfully perform steps complex data scienc...
# 67                                           build ai
# 68  build artificial neural networks tensorflow keras
# 69                    learn program python good level
# 70                  use python spark analyze big data
# 71  perform multitude data operations python popul...
# 72                               data scientist hired
# 73  develop distributed code scala programming lan...
# 74                    understand neural networks work
# 75                                          program r
# 76          use dataframes structured streaming spark
# 77                       learn work text files python
# 78  genuinely understand computer science algorith...
# 79     learn use data science machine learning python
# 80  write cipher decryption algorithm genetic algo...
# 81                     understand normal distribution
# 82  artificial neural networks anns deep neural ne...
# 83  apply gradient based supervised machine learni...
# 84               pass azure dp data fundamentals exam
# 85  learn deep learning works diagrams magical bla...
# 86  learn pass google official tensorflow develope...
# 87                         perform data preparation r
# 88  learn plotly create plots like bar charts line...
# 89                      understand implement word vec
# 90                 learn use tensorflow deep learning
# 91         apache spark foundation spark architecture
# 92  machine learning engineers earn average ideal ...
# 93  use adaptive algorithms improve b testing perf...
# 94  artificial intelligence machine learning deep ...
# 95            toolbox powerful computer vision models
# 96                      understand basics probability
# 97  build text classification system spam detectio...
# 98  derive solve linear regression model apply app...
# 99                        entire data science process
#
#                                      full_description  \
# 0   machine learning z ai python r chatgpt bonus p...
# 1   python data science machine learning bootcamp ...
# 2   data science course complete data science boot...
# 3   r programming z r data science real exercises ...
# 4   deep learning z neural networks ai chatgpt bon...
# 5   statistics data science business analysis p st...
# 6   data science z hands exercises chatgpt bonus p...
# 7   artificial intelligence z build ai incl chatgp...
# 8   machine learning data science generative ai py...
# 9   python z python data science real exercises p ...
# 10  spark python big data pyspark p strong learn l...
# 11  data analysis pandas python p strong student t...
# 12  complete machine learning data science bootcam...
# 13  apache spark scala hands big data p strong new...
# 14  complete guide tensorflow deep learning python...
# 15  data science machine learning bootcamp r p dat...
# 16  taming big data apache spark python hands p st...
# 17  nlp natural language processing python p welco...
# 18  introduction machine learning data science p s...
# 19  python machine learning data science mastercla...
# 20  data science natural language processing nlp p...
# 21  statistics business analytics data science z p...
# 22  tensorflow deep learning artificial intelligen...
# 23  artificial intelligence reinforcement learning...
# 24  dp azure data fundamentals exam prep day p str...
# 25  data science deep learning neural networks pyt...
# 26  tensorflow developer certificate zero mastery ...
# 27  r programming advanced analytics r data scienc...
# 28  interactive python dashboards plotly dash p st...
# 29  natural language processing deep learning pyth...
# 30  complete tensorflow keras deep learning bootca...
# 31  apache spark spark programming python beginner...
# 32  complete machine learning course python p em c...
# 33  bayesian machine learning python b testing p c...
# 34  machine learning absolute beginners level p st...
# 35  deep learning computer vision z ai chatgpt bon...
# 36  probability statistics business data science p...
# 37  deep learning advanced natural language proces...
# 38  deep learning prerequisites linear regression ...
# 39  intro data science quickstart guide ai chatgpt...
# 40  deep learning advanced computer vision gans ss...
# 41  complete data science machine learning bootcam...
# 42  statistics data analysis excel p strong em gt ...
# 43  deep learning convolutional neural networks py...
# 44  machine learning deep learning python r p look...
# 45  scala spark big data machine learning p learn ...
# 46  artificial intelligence machine learning busin...
# 47  mathematical foundations machine learning p ma...
# 48  advanced ai deep reinforcement learning python...
# 49  sql database design z learn ms sql server post...
# 50  deployment machine learning models p welcome d...
# 51  cluster analysis unsupervised machine learning...
# 52  r programming statistics data science p strong...
# 53  deep learning recurrent neural networks python...
# 54  data integration guide p according world econo...
# 55  pytorch deep learning python bootcamp p welcom...
# 56  deep learning prerequisites logistic regressio...
# 57  python machine learning financial analysis p r...
# 58  complete self driving car course applied deep ...
# 59  artificial intelligence business chatgpt bonus...
# 60  machine learning z ai python r chatgpt bonus p...
# 61  python data science machine learning bootcamp ...
# 62  data science course complete data science boot...
# 63  r programming z r data science real exercises ...
# 64  deep learning z neural networks ai chatgpt bon...
# 65  statistics data science business analysis p st...
# 66  data science z hands exercises chatgpt bonus p...
# 67  artificial intelligence z build ai incl chatgp...
# 68  machine learning data science generative ai py...
# 69  python z python data science real exercises p ...
# 70  spark python big data pyspark p strong learn l...
# 71  data analysis pandas python p strong student t...
# 72  complete machine learning data science bootcam...
# 73  apache spark scala hands big data p strong new...
# 74  complete guide tensorflow deep learning python...
# 75  data science machine learning bootcamp r p dat...
# 76  taming big data apache spark python hands p st...
# 77  nlp natural language processing python p welco...
# 78  introduction machine learning data science p s...
# 79  python machine learning data science mastercla...
# 80  data science natural language processing nlp p...
# 81  statistics business analytics data science z p...
# 82  tensorflow deep learning artificial intelligen...
# 83  artificial intelligence reinforcement learning...
# 84  dp azure data fundamentals exam prep day p str...
# 85  data science deep learning neural networks pyt...
# 86  tensorflow developer certificate zero mastery ...
# 87  r programming advanced analytics r data scienc...
# 88  interactive python dashboards plotly dash p st...
# 89  natural language processing deep learning pyth...
# 90  complete tensorflow keras deep learning bootca...
# 91  apache spark spark programming python beginner...
# 92  complete machine learning course python p em c...
# 93  bayesian machine learning python b testing p c...
# 94  machine learning absolute beginners level p st...
# 95  deep learning computer vision z ai chatgpt bon...
# 96  probability statistics business data science p...
# 97  deep learning advanced natural language proces...
# 98  deep learning prerequisites linear regression ...
# 99  intro data science quickstart guide ai chatgpt...
#
#                                         skills_tagged
# 0   {reinforcement learning, data preprocessing, m...
# 1   {tensorflow, deep learning, web scraping, sql,...
# 2   {tensorflow, data manipulation, statistical, d...
# 3   {r programming, statistical, statistical analy...
# 4   {tensorflow, deep learning, autoencoders, pyto...
# 5   {statistical, data visualization, statistical ...
# 6   {visualization, data analysis, data mining, ch...
# 7   {deep learning, chatgpt, artificial intelligen...
# 8   {tensorflow, sentiment analysis, data visualiz...
# 9   {python programming, visualization, statistica...
# 10  {dataframe, mapreduce, sql, amazon, pyspark, b...
# 11  {visualization, python programming language, d...
# 12  {tensorflow, data analysis, deep learning, apa...
# 13  {mapreduce, data analysis, dataset, cloud comp...
# 14  {tensorflow, reinforcement learning, deep lear...
# 15  {r programming language, deep learning, web sc...
# 16  {mapreduce, data analysis, cloud computing, am...
# 17  {sentiment analysis, machine learning, deep le...
# 18  {data analysis, data mining, big data, algorit...
# 19  {data analysis, k means clustering, amazon, na...
# 20  {sentiment analysis, deep learning, natural la...
# 21    {business analytics, statistical, data science}
# 22  {tensorflow, reinforcement learning, deep lear...
# 23  {reinforcement learning, q learning, deep lear...
# 24      {analytics, microsoft azure, cloud computing}
# 25  {tensorflow, machine learning algorithms, deep...
# 26  {tensorflow, build time, deep learning, comput...
# 27  {r programming, data analysis, statistical ana...
# 28  {data visualization, dashboard, visualization,...
# 29  {tensorflow, sentiment analysis, deep learning...
# 30  {tensorflow, data analysis, deep learning, aut...
# 31           {apache spark, data engineering, python}
# 32  {deep learning, computer vision, convolutional...
# 33  {reinforcement learning, analytics, b testing,...
# 34  {deep learning, machine learning, artificial i...
# 35  {deep learning, computer vision, chatgpt, arti...
# 36  {data science, probability, probability statis...
# 37  {tensorflow, sentiment analysis, deep learning...
# 38  {data analysis, deep learning, probability, ar...
# 39  {python, chatgpt, machine learning algorithms,...
# 40  {tensorflow, deep learning, computer vision, p...
# 41  {tensorflow, python programming, deep learning...
# 42  {data analysis, analysis variance anova, stati...
# 43  {tensorflow, sentiment analysis, deep learning...
# 44  {tensorflow, data manipulation, data analysis,...
# 45  {big data, scala, amazon web services, machine...
# 46  {machine learning, analytics, artificial intel...
# 47  {tensorflow, deep learning, pytorch, probabili...
# 48  {reinforcement learning, tensorflow, q learnin...
# 49  {mysql, database design, postgresql, analytics...
# 50  {ci cd, docker, continuous integration, jupyte...
# 51  {analytics, probability distribution, data min...
# 52  {data manipulation, r programming, data analys...
# 53  {tensorflow, sentiment analysis, deep learning...
# 54     {analytics, data integration, data encryption}
# 55  {deep learning, computer vision, pytorch, back...
# 56  {machine learning algorithms, deep learning, p...
# 57  {python programming, visualization, data analy...
# 58  {deep learning, computer vision, convolutional...
# 59  {chatgpt, artificial intelligence, q learning,...
# 60  {reinforcement learning, data preprocessing, m...
# 61  {tensorflow, deep learning, web scraping, sql,...
# 62  {tensorflow, data manipulation, statistical, d...
# 63  {r programming, statistical, statistical analy...
# 64  {tensorflow, deep learning, autoencoders, pyto...
# 65  {statistical, data visualization, statistical ...
# 66  {visualization, data analysis, data mining, ch...
# 67  {deep learning, chatgpt, artificial intelligen...
# 68  {tensorflow, sentiment analysis, data visualiz...
# 69  {python programming, visualization, statistica...
# 70  {dataframe, mapreduce, sql, amazon, pyspark, b...
# 71  {visualization, python programming language, d...
# 72  {tensorflow, data analysis, deep learning, apa...
# 73  {mapreduce, data analysis, dataset, cloud comp...
# 74  {tensorflow, reinforcement learning, deep lear...
# 75  {r programming language, deep learning, web sc...
# 76  {mapreduce, data analysis, cloud computing, am...
# 77  {sentiment analysis, machine learning, deep le...
# 78  {data analysis, data mining, big data, algorit...
# 79  {data analysis, k means clustering, amazon, na...
# 80  {sentiment analysis, deep learning, natural la...
# 81    {business analytics, statistical, data science}
# 82  {tensorflow, reinforcement learning, deep lear...
# 83  {reinforcement learning, q learning, deep lear...
# 84      {analytics, microsoft azure, cloud computing}
# 85  {tensorflow, machine learning algorithms, deep...
# 86  {tensorflow, build time, deep learning, comput...
# 87  {r programming, data analysis, statistical ana...
# 88  {data visualization, dashboard, visualization,...
# 89  {tensorflow, sentiment analysis, deep learning...
# 90  {tensorflow, data analysis, deep learning, aut...
# 91           {apache spark, data engineering, python}
# 92  {deep learning, computer vision, convolutional...
# 93  {reinforcement learning, analytics, b testing,...
# 94  {deep learning, machine learning, artificial i...
# 95  {deep learning, computer vision, chatgpt, arti...
# 96  {data science, probability, probability statis...
# 97  {tensorflow, sentiment analysis, deep learning...
# 98  {data analysis, deep learning, probability, ar...
# 99  {python, chatgpt, machine learning algorithms,...

# %%
import spacy
import pandas as pd
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

# Load SpaCy model for vectorization
nlp = spacy.load("en_core_web_md")

# Vectorize skills
#skill_vectors = [nlp(skill).vector for skill in skills_list]

# Perform hierarchical clustering
#Z = linkage(skill_vectors, method='ward')

import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt

# Text vectorization
vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(skills_list)

# Hierarchical clustering
Z = linkage(X.toarray(), 'ward')

# Plot dendrogram
plt.figure(figsize=(10, 7))
dendrogram(Z, labels=skills_list, leaf_rotation=90)
plt.title("Skills Hierarchical Clustering")
plt.show()

# From the dendrogram, decide the number of clusters or the level at which to cut the tree
# Then assign cluster names based on common themes in each cluster

from scipy.cluster.hierarchy import fcluster

# Determine the number of clusters, for example, by setting a threshold
distance_threshold = 1.5
clusters = fcluster(Z, distance_threshold, criterion='distance')
clusters
# Or determine by specifying the exact number of clusters desired
#k = 10
#clusters = fcluster(Z, k, criterion='maxclust')

from collections import Counter

# Assuming you have the following:
# clusters: an array with the cluster labels for each job title
# job_titles: an array with the corresponding job titles

# Create a dictionary where each key is a cluster and the value is a list of titles
clustered_titles = {i: [] for i in range(1, len(set(clusters))+1)}
for title, cluster_label in zip(skills_list, clusters):
    clustered_titles[cluster_label].append(title)

# For each cluster, find the most common words
cluster_names = {}
for cluster, titles in clustered_titles.items():
    # Flatten the list of titles into a list of words
    words = " ".join(titles).lower().split()
    # Count the frequency of each word
    word_counts = Counter(words)
    # Remove common stop words (optional, depends on your data)
    for stop_word in [ 'and', 'the', '-']:
        if stop_word in word_counts:
            del word_counts[stop_word]
    # Take the top 3 most common words as the name
    cluster_names[cluster] = ' '.join([word for word, _ in word_counts.most_common(3)])
clustered_titles
# Now cluster_names contains a 'name' for each cluster based on the most common words
########################
xs = set()
for i,each in enumerate(df_c_cleaned_2["skills_tagged"]):
    if len(each)==0:
        print(i)
        print(df_c_cleaned_2[i:i+1]["title"].unique())
        print(df_c_cleaned_2[i:i+1]["description"].unique())
        print("/n")
    for each_v in each:
        xs.add(each_v)

# %%
# train a spacy model to identify skills 
# create entities 
import spacy
from spacy.matcher import PhraseMatcher
from spacy.tokens import Span
from spacy.util import filter_spans

nlp = spacy.load("en_core_web_sm")  # Load the model
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")  # Create the matcher object


# Convert the skills list to Doc objects and add them as patterns to the matcher
patterns = [nlp.make_doc(skill) for skill in skills_list]
matcher.add("Skills", patterns)


def get_entities(TRAIN_DATA):
    for _, annotations in TRAIN_DATA:
        for ent in annotations.get('entities'):
            print(ent)

TRAIN_DATA = []

# Loop through the job descriptions and create training data
for job_description in job_descriptions:
    # Process the job description to create a Spacy Doc
    doc = nlp(job_description)
    # Match the patterns to the doc
    matches = matcher(doc)
    # Create Span objects for the matched sequences
    spans = [Span(doc, start, end, label="SKILLS") for match_id, start, end in matches]
    # Filter the spans to remove overlaps
    #print(spans)
    filtered_spans = filter_spans(spans)
    #print(spans)
    entities = [(span.start_char, span.end_char, span) for span in filtered_spans]
    TRAIN_DATA.append((job_description, {"entities": entities}))

#print(TRAIN_DATA)





# train the model

#train the model 
starting_fresh = False
# Load a pre-existing spaCy model
nlp = spacy.load('en_core_web_sm')  # for example
import random
from spacy.util import minibatch
# Get the Named Entity Recognizer component in the pipeline
ner = nlp.get_pipe('ner')
from spacy.training import Example
from pathlib import Path

# Add new entity labels to 'ner'
for _, annotations in TRAIN_DATA:
    for start,end,label in annotations.get('entities'):
        #print(label)
        ner.add_label(str(label))


# Disable other pipes during training
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe != 'ner']


# Begin training
with nlp.disable_pipes(*unaffected_pipes):
    if starting_fresh:
        nlp.begin_training()

    for itn in range(5):
        random.shuffle(TRAIN_DATA)
        losses = {}

        # Batch up the examples using spaCy's minibatch
        for batch in minibatch(TRAIN_DATA, size=2):
            examples = []
            for text, annotations in batch:
                # Create a Spacy Doc from the text
                doc = nlp.make_doc(text)
                # Create an Example using the annotations
                example = Example.from_dict(doc, annotations)
                examples.append(example)

            # Update the model
            nlp.update(
                examples,
                drop=0.5,  # Dropout - make it harder to memorize data
                losses=losses
            )
        print(losses)

'''
from pathlib import Path
output_dir = Path('/Users/nyzy/nitzmali/job_transition_pathway/models/skills_tag_spacy_nlp_model')
nlp.to_disk(output_dir)
print("Saved model to", output_dir)
'''


# Split your TRAIN_DATA into train, validate and test sets
def train_test_val_split(data, test_size=0.2, val_size=0.25, random_state=42):
    # Calculate actual validation set size of the remaining data after test split
    val_size_adjusted = val_size / (1 - test_size)
    # Split off test set from available data
    train_val_data, test_data = train_test_split(data, test_size=test_size, random_state=random_state)
    # Split remaining data into training and validation sets
    train_data, val_data = train_test_split(train_val_data, test_size=val_size_adjusted, random_state=random_state)
    return train_data, val_data, test_data
train_data, val_data, test_data = train_test_val_split(TRAIN_DATA, test_size=0.2, val_size=0.25)


#########################################################################################
# Load the model you want to evaluate
from spacy import displacy
nlp = spacy.load('/Users/nyzy/nitzmali/job_transition_pathway/models/skills_tag_spacy_nlp_model')  # replace with your model name

# Split your TRAIN_DATA into train, validate and test sets
train_data, val_data, test_data = train_test_val_split(TRAIN_DATA, test_size=0.2, val_size=0.25)

# Convert the validation data to spaCy's Example format
examples = []
for input_, annots in val_data:
    pred = nlp(input_)
    example = Example.from_dict(pred, annots)
    examples.append(example)


# Use the Scorer to score the examples
scorer = Scorer(nlp)
scores = scorer.score(examples)


precision = scores['ents_p']
recall = scores['ents_r']
f_score = scores['ents_f']

print(f"Precision: {precision}")
print(f"Recall: {recall}")
print(f"F-score: {f_score}")

examples[0]


# Assume 'nlp' is your loaded NLP model
for text, annots in val_data[3:5]:  # Let's use val_data as an example
    doc = nlp(text)  # Process the text to predict entities

    '''
    print("Predictions by model:")
    for ent in doc.ents:
        print("Predictions")
        #print(ent.text, ent.start_char, ent.end_char, ent.label_)

    # Now print the correct data for comparison
    print("\nCorrect labels:")
    for start, end, label in annots['entities']:
        print("Actual")
        #print(text[start:end], start, end, label)
    '''
    # You can use displacy here as well if you prefer visual comparison
    displacy.render(doc, style="ent", jupyter=True)

    # Adding a separation for readability between different examples
    print("\n" + "-" * 50 + "\n")
